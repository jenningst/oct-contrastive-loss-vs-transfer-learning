# %%
import os
import sys
import math
import matplotlib.pyplot as plt
import tensorflow as tf
import tensorflow_datasets as tfds

from tensorflow import keras
from tensorflow.keras import layers

# %% [markdown]
# ## set up paths, model parameters, and grab data
#
# First, grab data directories, note: test_dir will contain the labeled data and training_dir needs to be entirely unlabeled

# %%
data_dir = './../fourthbrain-capstone/data/raw/OCT2017/'
test_dir = data_dir + "test/"
training_dir = data_dir + 'unlabeled_data_20k_images'

# %% [markdown]
# After we have our directories, we can run `data_utils` and use the `prepare_dataset` udf. This will call the necessary `image_dataset_from_directory` commands for the unlabeled and labeled datasets.<br> **Note**: test_data, which is 1000 images, will have 1000 images and be broken down into a validation and a test dataset (usually at 20%, 80% respectively).
#
#
# We define some parameters below:
#
# `width` is utilized in the RNN - this can be thought of as the max width of the final dense layer, as well as some layers within the teacher net
#
# `temperature` is used in the contrastive loss function for scaling, this helps it learn from 'hard negatives'
#
#
# **Augmentation**: Stronger augmentations for contrastive, weaker ones for supervised training
#
# **jitter' refers to the color scaling, **brightness** refers to strength of contrast, **min_area** related to cropping.

# %%
image_size = 224
image_channels = 3
num_epochs = 100
batch_size = 32 
width = 128 
temperature = 0.1 
contrastive_augmentation = {"min_area": 0.25, "brightness": 0.6, "jitter": 0.2} 
classification_augmentation = {"min_area": 0.75, "brightness": 0.3, "jitter": 0.1}

# %%
# add the project dir to sys.path in order to access modules for import
sys.path.append(os.path.dirname(os.getcwd()))

from src.utils.data_utils import prepare_dataset

# %%
train_dataset, labeled_train_dataset, test_dataset = prepare_dataset(training_dir,
                    test_dir,
                    image_size=image_size,
                    batch_size=batch_size,
                    seed = 1234,
                    val_split = 0.2)

#below we see in the output that 20k images belong to 1 class - this is because they are UNLABELED
# Out:
# Found 20000 files belonging to 1 classes.
# Found 1000 files belonging to 4 classes.
# Using 800 files for training.
# Found 1000 files belonging to 4 classes.
# Using 200 files for validation.
# 2022-06-24 17:09:46.099076: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ## Image augmentations

# %%
#Distorts the color distibutions of images
class RandomColorAffine(layers.Layer):
    def __init__(self, brightness=0, jitter=0, **kwargs):
        super().__init__(**kwargs)

        self.brightness = brightness
        self.jitter = jitter

    def get_config(self):
        """Get config from input, this is the args in the previous cell"""
        config = super().get_config()
        config.update({"brightness": self.brightness, "jitter": self.jitter})
        return config

    def call(self, images, training=True):
        """call function utilized in keras.model setup and informs how to utilize RAndomColorAffine class
        note: No test step, only called in training"""
        if training:
            batch_size = tf.shape(images)[0]

            # Same for all colors
            brightness_scales = 1 + tf.random.uniform(
                (batch_size, 1, 1, 1), minval=-self.brightness, maxval=self.brightness
            )
            # Different for all colors
            jitter_matrices = tf.random.uniform(
                (batch_size, 1, 3, 3), minval=-self.jitter, maxval=self.jitter
            )

            color_transforms = (
                tf.eye(3, batch_shape=[batch_size, 1]) * brightness_scales
                + jitter_matrices
            )
            images = tf.clip_by_value(tf.matmul(images, color_transforms), 0, 1)
        return images


# Image augmentation module
def get_augmenter(min_area, brightness, jitter):
    """get_augmentor reads in configs and then applies pixel scaling, 
    image augmentation through flipping/cropping, and RandomColorAffine"""
    zoom_factor = 1.0 - math.sqrt(min_area)
    return keras.Sequential(
        [
            keras.Input(shape=(image_size, image_size, image_channels)),
            layers.Rescaling(1 / 255),
            layers.RandomFlip("horizontal"),
            layers.RandomTranslation(zoom_factor / 2, zoom_factor / 2),
            layers.RandomZoom((-zoom_factor, 0.0), (-zoom_factor, 0.0)),
            RandomColorAffine(brightness, jitter),
        ]
    )


def visualize_augmentations(num_images):
    """visualization augmentations reads in a number of images and applies the augmentation at various strengths. 
    This is then plotted so the user can get a feel of how the images are being processed"""
    # Sample a batch from a dataset
    images = next(iter(train_dataset))[0][0][:num_images]
    # Apply augmentations
    augmented_images = zip(
        images,
        get_augmenter(**classification_augmentation)(images),
        get_augmenter(**contrastive_augmentation)(images),
        get_augmenter(**contrastive_augmentation)(images),
    )
    row_titles = [
        "Original:",
        "Weakly augmented:",
        "Strongly augmented:",
        "Strongly augmented:",
    ]
    plt.figure(figsize=(num_images * 2.2, 4 * 2.2), dpi=100)
    for column, image_row in enumerate(augmented_images):
        for row, image in enumerate(image_row):
            plt.subplot(4, num_images, row * num_images + column + 1)
            plt.imshow(image)
            if column == 0:
                plt.title(row_titles[row], loc="left")
            plt.axis("off")
    plt.tight_layout()


visualize_augmentations(num_images=8)
# Out:
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ## encoder architecture

# %%
# Define the encoder architecture

#call down resnet50, specifiy the input shape, and take away the weights/top
resnet50 = tf.keras.applications.resnet50.ResNet50(
    include_top=False,
    weights=None,
    input_shape=(image_size, image_size, image_channels))

def get_resnet_encoder(resnet, data, image_size, image_channels, width):
    """set up the get_resnet_encoder. 
    This model architecture will be used in the teacher net and passed to the student net
    
    Note: The output of this net has a FC layer with a relu activation and is of width nodes. 
    This gets passed into the linear probe or the projection heads of the teacher net and the FC layer of width number of classes for the student net"""
    image_batch, _ = next(iter(data))
    feature_batch = resnet(image_batch)
    global_average_layer = tf.keras.layers.GlobalAveragePooling2D()
    dense = layers.Dense(width, activation = 'relu')
    
    inputs = tf.keras.Input(shape = (image_size, image_size, image_channels))
    x = resnet(inputs)
    x = global_average_layer(x)
    outputs = dense(x)
    encoder = keras.Model(inputs, outputs)
    return encoder

# %%
get_resnet_encoder(resnet50,labeled_train_dataset,image_size, image_channels, width).summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  resnet50 (Functional)       (None, 7, 7, 2048)        23587712
#
#  global_average_pooling2d (G  (None, 2048)             0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 128)               262272
#
# =================================================================
# Total params: 23,849,984
# Trainable params: 23,796,864
# Non-trainable params: 53,120
# _________________________________________________________________

# %% [markdown]
# ## Supervised baseline model
# Baseline supervised training with random initialization - here we'll see how a standard resnet50 performs

# %%
baseline_model = keras.Sequential(
    [
        keras.Input(shape=(image_size, image_size, image_channels)),
        get_augmenter(**classification_augmentation),
        get_resnet_encoder(resnet50, labeled_train_dataset, image_size, image_channels, width),
        layers.Dense(4),
    ],
    name="baseline_model",
)
baseline_model.compile(
    optimizer=keras.optimizers.Adam(),
    loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=[keras.metrics.SparseCategoricalAccuracy(name="acc"),
            keras.metrics.TopKCategoricalAccuracy(k = 1, name="top1_acc"),
            keras.metrics.TopKCategoricalAccuracy(k = 2, name="top2_acc"),
            keras.metrics.TopKCategoricalAccuracy(k = 3, name="top3_acc"), 
            ],
)

baseline_model.summary()
# Out:
# Model: "baseline_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential_3 (Sequential)   (None, 224, 224, 3)       0
#
#  model_1 (Functional)        (None, 128)               23849984
#
#  dense_2 (Dense)             (None, 4)                 516
#
# =================================================================
# Total params: 23,850,500
# Trainable params: 23,797,380
# Non-trainable params: 53,120
# _________________________________________________________________

# %%
baseline_history = baseline_model.fit(
    labeled_train_dataset, epochs=num_epochs, validation_data=test_dataset
)

print(
    "Maximal validation accuracy: {:.2f}%".format(
        max(baseline_history.history["val_acc"]) * 100
    )
)
# Out:
# Epoch 1/100
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3
# 25/25 [==============================] - 173s 7s/step - loss: 2.2516 - acc: 0.3113 - top1_acc: 0.1900 - top2_acc: 0.4013 - top3_acc: 0.7887 - val_loss: 139.3186 - val_acc: 0.2600 - val_top1_acc: 0.0000e+00 - val_top2_acc: 0.0000e+00 - val_top3_acc: 1.0000
# Epoch 2/100
# 25/25 [==============================] - 166s 7s/step - loss: 1.6646 - acc: 0.2750 - top1_acc: 0.3938 - top2_acc: 0.6200 - top3_acc: 0.7900 - val_loss: 1.3828 - val_acc: 0.3000 - val_top1_acc: 0.0000e+00 - val_top2_acc: 0.0300 - val_top3_acc: 1.0000
# Epoch 3/100
# 25/25 [==============================] - 165s 7s/step - loss: 1.2236 - acc: 0.4613 - top1_acc: 0.2862 - top2_acc: 0.4112 - top3_acc: 0.5750 - val_loss: 1.5271 - val_acc: 0.2850 - val_top1_acc: 0.2550 - val_top2_acc: 1.0000 - val_top3_acc: 1.0000
# Epoch 4/100
# 25/25 [==============================] - 167s 7s/step - loss: 1.0140 - acc: 0.5600 - top1_acc: 0.2837 - top2_acc: 0.3800 - top3_acc: 0.5337 - val_loss: 2.0590 - val_acc: 0.2400 - val_top1_acc: 1.0000 - val_top2_acc: 1.0000 - val_top3_acc: 1.0000
# Epoch 5/100
# 25/25 [==============================] - 165s 7s/step - loss: 1.0248 - acc: 0.5387 - top1_acc: 0.2675 - top2_acc: 0.3250 - top3_acc: 0.4963 - val_loss: 2.2027 - val_acc: 0.2400 - val_top1_acc: 0.9800 - val_top2_acc: 0.9800 - val_top3_acc: 0.9900
# Epoch 6/100
# 25/25 [==============================] - 166s 7s/step - loss: 0.9480 - acc: 0.5825 - top1_acc: 0.2488 - top2_acc: 0.3038 - top3_acc: 0.5238 - val_loss: 3.7136 - val_acc: 0.2400 - val_top1_acc: 1.0000 - val_top2_acc: 1.0000 - val_top3_acc: 1.0000
# Epoch 7/100
# 25/25 [==============================] - 166s 7s/step - loss: 0.9506 - acc: 0.5888 - top1_acc: 0.2475 - top2_acc: 0.3150 - top3_acc: 0.4863 - val_loss: 5.2299 - val_acc: 0.2400 - val_top1_acc: 1.0000 - val_top2_acc: 1.0000 - val_top3_acc: 1.0000
# Epoch 8/100
# 25/25 [==============================] - 165s 7s/step - loss: 0.8347 - acc: 0.6237 - top1_acc: 0.2575 - top2_acc: 0.3000 - top3_acc: 0.5275 - val_loss: 5.2907 - val_acc: 0.2400 - val_top1_acc: 0.9900 - val_top2_acc: 0.9900 - val_top3_acc: 0.9900
# Epoch 9/100
# 25/25 [==============================] - 166s 7s/step - loss: 0.8901 - acc: 0.6313 - top1_acc: 0.2800 - top2_acc: 0.3000 - top3_acc: 0.5412 - val_loss: 2.4039 - val_acc: 0.2400 - val_top1_acc: 0.9650 - val_top2_acc: 0.9750 - val_top3_acc: 0.9900
# Epoch 10/100
# 25/25 [==============================] - 165s 7s/step - loss: 0.8563 - acc: 0.6000 - top1_acc: 0.2512 - top2_acc: 0.2800 - top3_acc: 0.5113 - val_loss: 2.3530 - val_acc: 0.2350 - val_top1_acc: 0.9650 - val_top2_acc: 0.9750 - val_top3_acc: 0.9950
# Epoch 11/100
# 25/25 [==============================] - 168s 7s/step - loss: 0.7321 - acc: 0.6975 - top1_acc: 0.2738 - top2_acc: 0.2912 - top3_acc: 0.5225 - val_loss: 2.8903 - val_acc: 0.2400 - val_top1_acc: 0.9400 - val_top2_acc: 0.9550 - val_top3_acc: 0.9950
# Epoch 12/100
# 25/25 [==============================] - 169s 7s/step - loss: 0.7200 - acc: 0.7113 - top1_acc: 0.2625 - top2_acc: 0.2837 - top3_acc: 0.5713 - val_loss: 1.7356 - val_acc: 0.3050 - val_top1_acc: 0.0100 - val_top2_acc: 0.0250 - val_top3_acc: 0.8350
# Epoch 13/100
# 25/25 [==============================] - 174s 7s/step - loss: 0.6931 - acc: 0.7337 - top1_acc: 0.2675 - top2_acc: 0.3212 - top3_acc: 0.5038 - val_loss: 4.3454 - val_acc: 0.2400 - val_top1_acc: 0.9250 - val_top2_acc: 1.0000 - val_top3_acc: 1.0000
# Epoch 14/100
# 25/25 [==============================] - 172s 7s/step - loss: 0.6358 - acc: 0.7850 - top1_acc: 0.2625 - top2_acc: 0.3587 - top3_acc: 0.5475 - val_loss: 0.7822 - val_acc: 0.7250 - val_top1_acc: 0.3450 - val_top2_acc: 0.4800 - val_top3_acc: 0.5900
# Epoch 15/100
# 25/25 [==============================] - 167s 7s/step - loss: 0.4821 - acc: 0.8462 - top1_acc: 0.2525 - top2_acc: 0.3638 - top3_acc: 0.5575 - val_loss: 4.1462 - val_acc: 0.2750 - val_top1_acc: 0.8000 - val_top2_acc: 0.8650 - val_top3_acc: 0.9050
# Epoch 16/100
# 25/25 [==============================] - 166s 7s/step - loss: 0.4274 - acc: 0.8450 - top1_acc: 0.2625 - top2_acc: 0.4062 - top3_acc: 0.5050 - val_loss: 1.0810 - val_acc: 0.6300 - val_top1_acc: 0.0650 - val_top2_acc: 0.1950 - val_top3_acc: 0.2700
# Epoch 17/100
# 25/25 [==============================] - 166s 7s/step - loss: 0.4015 - acc: 0.8550 - top1_acc: 0.2562 - top2_acc: 0.4400 - top3_acc: 0.5888 - val_loss: 3.2353 - val_acc: 0.6450 - val_top1_acc: 0.2150 - val_top2_acc: 0.4000 - val_top3_acc: 0.5450
# Epoch 18/100
# 25/25 [==============================] - 167s 7s/step - loss: 0.3950 - acc: 0.8775 - top1_acc: 0.2463 - top2_acc: 0.4187 - top3_acc: 0.6137 - val_loss: 9.3007 - val_acc: 0.3750 - val_top1_acc: 0.8400 - val_top2_acc: 0.8800 - val_top3_acc: 0.9200
# Epoch 19/100
# 25/25 [==============================] - 166s 7s/step - loss: 0.3736 - acc: 0.8775 - top1_acc: 0.2562 - top2_acc: 0.4913 - top3_acc: 0.6413 - val_loss: 0.5336 - val_acc: 0.8200 - val_top1_acc: 0.2800 - val_top2_acc: 0.5550 - val_top3_acc: 0.6150
# Epoch 20/100
# 25/25 [==============================] - 165s 7s/step - loss: 0.2983 - acc: 0.9000 - top1_acc: 0.2512 - top2_acc: 0.4963 - top3_acc: 0.6400 - val_loss: 1.4299 - val_acc: 0.6700 - val_top1_acc: 0.1800 - val_top2_acc: 0.5450 - val_top3_acc: 0.6050
# Epoch 21/100
# 25/25 [==============================] - 164s 7s/step - loss: 0.2089 - acc: 0.9375 - top1_acc: 0.2612 - top2_acc: 0.5663 - top3_acc: 0.6975 - val_loss: 1.1771 - val_acc: 0.6950 - val_top1_acc: 0.4100 - val_top2_acc: 0.6800 - val_top3_acc: 0.7250
# Epoch 22/100
# 25/25 [==============================] - 169s 7s/step - loss: 0.2775 - acc: 0.9200 - top1_acc: 0.2512 - top2_acc: 0.4737 - top3_acc: 0.6275 - val_loss: 0.6285 - val_acc: 0.8450 - val_top1_acc: 0.2150 - val_top2_acc: 0.4450 - val_top3_acc: 0.7200
# Epoch 23/100
# 25/25 [==============================] - 167s 7s/step - loss: 0.1653 - acc: 0.9400 - top1_acc: 0.2525 - top2_acc: 0.5113 - top3_acc: 0.7163 - val_loss: 0.3638 - val_acc: 0.8850 - val_top1_acc: 0.2450 - val_top2_acc: 0.3850 - val_top3_acc: 0.6300
# Epoch 24/100
# 25/25 [==============================] - 167s 7s/step - loss: 0.2131 - acc: 0.9275 - top1_acc: 0.2600 - top2_acc: 0.4925 - top3_acc: 0.6925 - val_loss: 0.9404 - val_acc: 0.7850 - val_top1_acc: 0.3550 - val_top2_acc: 0.5150 - val_top3_acc: 0.6100
# Epoch 25/100
# 25/25 [==============================] - 167s 7s/step - loss: 0.1517 - acc: 0.9488 - top1_acc: 0.2425 - top2_acc: 0.4925 - top3_acc: 0.6900 - val_loss: 0.3650 - val_acc: 0.9250 - val_top1_acc: 0.2600 - val_top2_acc: 0.4950 - val_top3_acc: 0.7250
# Epoch 26/100
# 25/25 [==============================] - 168s 7s/step - loss: 0.1958 - acc: 0.9450 - top1_acc: 0.2488 - top2_acc: 0.4762 - top3_acc: 0.6625 - val_loss: 4.1755 - val_acc: 0.5400 - val_top1_acc: 0.0050 - val_top2_acc: 0.0650 - val_top3_acc: 0.2950
# Epoch 27/100
# 25/25 [==============================] - 171s 7s/step - loss: 0.1637 - acc: 0.9438 - top1_acc: 0.2525 - top2_acc: 0.4925 - top3_acc: 0.6475 - val_loss: 0.6821 - val_acc: 0.8300 - val_top1_acc: 0.2250 - val_top2_acc: 0.5000 - val_top3_acc: 0.6850
# Epoch 28/100
# 25/25 [==============================] - 168s 7s/step - loss: 0.1558 - acc: 0.9538 - top1_acc: 0.2562 - top2_acc: 0.5337 - top3_acc: 0.6737 - val_loss: 1.9089 - val_acc: 0.7200 - val_top1_acc: 0.0650 - val_top2_acc: 0.1700 - val_top3_acc: 0.4100
# Epoch 29/100
# 25/25 [==============================] - 165s 7s/step - loss: 0.1330 - acc: 0.9538 - top1_acc: 0.2562 - top2_acc: 0.5113 - top3_acc: 0.6687 - val_loss: 2.4017 - val_acc: 0.6500 - val_top1_acc: 0.2300 - val_top2_acc: 0.6300 - val_top3_acc: 0.9800
# Epoch 30/100
# 25/25 [==============================] - 164s 7s/step - loss: 0.1122 - acc: 0.9638 - top1_acc: 0.2500 - top2_acc: 0.4900 - top3_acc: 0.6725 - val_loss: 6.0548 - val_acc: 0.3850 - val_top1_acc: 0.1350 - val_top2_acc: 0.2900 - val_top3_acc: 0.8300
# Epoch 31/100
# 25/25 [==============================] - 165s 7s/step - loss: 0.1057 - acc: 0.9663 - top1_acc: 0.2562 - top2_acc: 0.4988 - top3_acc: 0.6900 - val_loss: 5.2466 - val_acc: 0.4050 - val_top1_acc: 0.4750 - val_top2_acc: 0.9450 - val_top3_acc: 1.0000
# Epoch 32/100
# 25/25 [==============================] - 164s 7s/step - loss: 0.1094 - acc: 0.9688 - top1_acc: 0.2463 - top2_acc: 0.5150 - top3_acc: 0.6862 - val_loss: 0.3128 - val_acc: 0.9300 - val_top1_acc: 0.2450 - val_top2_acc: 0.5450 - val_top3_acc: 0.7000
# Epoch 33/100
# 25/25 [==============================] - 165s 7s/step - loss: 0.1436 - acc: 0.9538 - top1_acc: 0.2575 - top2_acc: 0.5550 - top3_acc: 0.7013 - val_loss: 3.4474 - val_acc: 0.6000 - val_top1_acc: 0.2750 - val_top2_acc: 0.5400 - val_top3_acc: 0.8100
# Epoch 34/100
# 25/25 [==============================] - 165s 7s/step - loss: 0.1280 - acc: 0.9638 - top1_acc: 0.2575 - top2_acc: 0.5450 - top3_acc: 0.6925 - val_loss: 0.6413 - val_acc: 0.8850 - val_top1_acc: 0.2050 - val_top2_acc: 0.5100 - val_top3_acc: 0.6100
# Epoch 35/100
# 25/25 [==============================] - 165s 7s/step - loss: 0.1203 - acc: 0.9538 - top1_acc: 0.2575 - top2_acc: 0.5525 - top3_acc: 0.6913 - val_loss: 0.5055 - val_acc: 0.9150 - val_top1_acc: 0.2150 - val_top2_acc: 0.5500 - val_top3_acc: 0.7100
# Epoch 36/100
# 25/25 [==============================] - 165s 7s/step - loss: 0.1118 - acc: 0.9688 - top1_acc: 0.2550 - top2_acc: 0.5562 - top3_acc: 0.7212 - val_loss: 0.1219 - val_acc: 0.9850 - val_top1_acc: 0.2350 - val_top2_acc: 0.5850 - val_top3_acc: 0.7000
# Epoch 37/100
# 25/25 [==============================] - 165s 7s/step - loss: 0.1291 - acc: 0.9588 - top1_acc: 0.2537 - top2_acc: 0.5888 - top3_acc: 0.7287 - val_loss: 0.9761 - val_acc: 0.8250 - val_top1_acc: 0.2400 - val_top2_acc: 0.5900 - val_top3_acc: 0.7350
# Epoch 38/100
# 25/25 [==============================] - 165s 7s/step - loss: 0.1042 - acc: 0.9600 - top1_acc: 0.2500 - top2_acc: 0.6737 - top3_acc: 0.7350 - val_loss: 0.4708 - val_acc: 0.8950 - val_top1_acc: 0.1600 - val_top2_acc: 0.6400 - val_top3_acc: 0.7150
# Epoch 39/100
# 25/25 [==============================] - 166s 7s/step - loss: 0.0786 - acc: 0.9737 - top1_acc: 0.2450 - top2_acc: 0.6575 - top3_acc: 0.7175 - val_loss: 0.1964 - val_acc: 0.9300 - val_top1_acc: 0.2500 - val_top2_acc: 0.6900 - val_top3_acc: 0.7300
# Epoch 40/100
# 25/25 [==============================] - 169s 7s/step - loss: 0.1210 - acc: 0.9613 - top1_acc: 0.2550 - top2_acc: 0.6400 - top3_acc: 0.6988 - val_loss: 3.2467 - val_acc: 0.6550 - val_top1_acc: 0.2000 - val_top2_acc: 0.5000 - val_top3_acc: 0.6400
# Epoch 41/100
# 25/25 [==============================] - 173s 7s/step - loss: 0.1282 - acc: 0.9525 - top1_acc: 0.2512 - top2_acc: 0.6100 - top3_acc: 0.6950 - val_loss: 1.2077 - val_acc: 0.8550 - val_top1_acc: 0.3250 - val_top2_acc: 0.6950 - val_top3_acc: 0.7500
# Epoch 42/100
# 25/25 [==============================] - 171s 7s/step - loss: 0.0957 - acc: 0.9725 - top1_acc: 0.2650 - top2_acc: 0.6787 - top3_acc: 0.7300 - val_loss: 4.2918 - val_acc: 0.5900 - val_top1_acc: 0.1700 - val_top2_acc: 0.5950 - val_top3_acc: 0.9400
# Epoch 43/100
# 25/25 [==============================] - 165s 7s/step - loss: 0.0708 - acc: 0.9737 - top1_acc: 0.2512 - top2_acc: 0.6750 - top3_acc: 0.7362 - val_loss: 0.9293 - val_acc: 0.7550 - val_top1_acc: 0.3050 - val_top2_acc: 0.7100 - val_top3_acc: 0.7650
# Epoch 44/100
# 25/25 [==============================] - 166s 7s/step - loss: 0.0890 - acc: 0.9775 - top1_acc: 0.2550 - top2_acc: 0.6025 - top3_acc: 0.7250 - val_loss: 0.5273 - val_acc: 0.8400 - val_top1_acc: 0.2450 - val_top2_acc: 0.7100 - val_top3_acc: 0.7600
# Epoch 45/100
# 25/25 [==============================] - 167s 7s/step - loss: 0.0721 - acc: 0.9787 - top1_acc: 0.2587 - top2_acc: 0.5975 - top3_acc: 0.7200 - val_loss: 3.5334 - val_acc: 0.5450 - val_top1_acc: 0.3650 - val_top2_acc: 0.7050 - val_top3_acc: 0.9650
# Epoch 46/100
# 25/25 [==============================] - 164s 7s/step - loss: 0.0745 - acc: 0.9712 - top1_acc: 0.2500 - top2_acc: 0.6413 - top3_acc: 0.7350 - val_loss: 1.1056 - val_acc: 0.7600 - val_top1_acc: 0.3150 - val_top2_acc: 0.7450 - val_top3_acc: 0.8200
# Epoch 47/100
# 25/25 [==============================] - 165s 7s/step - loss: 0.0928 - acc: 0.9700 - top1_acc: 0.2537 - top2_acc: 0.6150 - top3_acc: 0.7350 - val_loss: 1.3890 - val_acc: 0.7300 - val_top1_acc: 0.4300 - val_top2_acc: 0.7350 - val_top3_acc: 0.7900
# Epoch 48/100
# 25/25 [==============================] - 165s 7s/step - loss: 0.0439 - acc: 0.9875 - top1_acc: 0.2525 - top2_acc: 0.6425 - top3_acc: 0.7362 - val_loss: 0.1231 - val_acc: 0.9550 - val_top1_acc: 0.2150 - val_top2_acc: 0.6700 - val_top3_acc: 0.7200
# Epoch 49/100
# 25/25 [==============================] - 165s 7s/step - loss: 0.0266 - acc: 0.9862 - top1_acc: 0.2550 - top2_acc: 0.6562 - top3_acc: 0.7437 - val_loss: 0.5812 - val_acc: 0.8750 - val_top1_acc: 0.2350 - val_top2_acc: 0.6750 - val_top3_acc: 0.7750
# Epoch 50/100
# 25/25 [==============================] - 164s 7s/step - loss: 0.0447 - acc: 0.9812 - top1_acc: 0.2562 - top2_acc: 0.6900 - top3_acc: 0.7437 - val_loss: 0.4178 - val_acc: 0.8750 - val_top1_acc: 0.2750 - val_top2_acc: 0.7150 - val_top3_acc: 0.7450
# Epoch 51/100
# 25/25 [==============================] - 165s 7s/step - loss: 0.0549 - acc: 0.9812 - top1_acc: 0.2525 - top2_acc: 0.6825 - top3_acc: 0.7437 - val_loss: 0.0494 - val_acc: 0.9800 - val_top1_acc: 0.2450 - val_top2_acc: 0.7100 - val_top3_acc: 0.7200
# Epoch 52/100
# 25/25 [==============================] - 164s 7s/step - loss: 0.1079 - acc: 0.9625 - top1_acc: 0.2550 - top2_acc: 0.6837 - top3_acc: 0.7600 - val_loss: 2.6231 - val_acc: 0.7400 - val_top1_acc: 0.0000e+00 - val_top2_acc: 0.2850 - val_top3_acc: 0.6850
# Epoch 53/100
# 25/25 [==============================] - 166s 7s/step - loss: 0.1088 - acc: 0.9625 - top1_acc: 0.2500 - top2_acc: 0.6812 - top3_acc: 0.7337 - val_loss: 1.2632 - val_acc: 0.7250 - val_top1_acc: 0.3250 - val_top2_acc: 0.7500 - val_top3_acc: 0.8050
# Epoch 54/100
# 25/25 [==============================] - 169s 7s/step - loss: 0.1444 - acc: 0.9588 - top1_acc: 0.2550 - top2_acc: 0.6450 - top3_acc: 0.7400 - val_loss: 2.1164 - val_acc: 0.6500 - val_top1_acc: 0.3050 - val_top2_acc: 0.6800 - val_top3_acc: 0.9050
# Epoch 55/100
# 25/25 [==============================] - 173s 7s/step - loss: 0.0906 - acc: 0.9750 - top1_acc: 0.2537 - top2_acc: 0.6037 - top3_acc: 0.7362 - val_loss: 0.5304 - val_acc: 0.8100 - val_top1_acc: 0.1000 - val_top2_acc: 0.4450 - val_top3_acc: 0.5950
# Epoch 56/100
# 25/25 [==============================] - 172s 7s/step - loss: 0.0679 - acc: 0.9800 - top1_acc: 0.2550 - top2_acc: 0.6637 - top3_acc: 0.7200 - val_loss: 0.4390 - val_acc: 0.8600 - val_top1_acc: 0.2200 - val_top2_acc: 0.6550 - val_top3_acc: 0.7950
# Epoch 57/100
# 25/25 [==============================] - 167s 7s/step - loss: 0.0398 - acc: 0.9862 - top1_acc: 0.2512 - top2_acc: 0.7100 - top3_acc: 0.7462 - val_loss: 0.2305 - val_acc: 0.9350 - val_top1_acc: 0.1750 - val_top2_acc: 0.7200 - val_top3_acc: 0.7300
# Epoch 58/100
# 25/25 [==============================] - 167s 7s/step - loss: 0.0578 - acc: 0.9812 - top1_acc: 0.2537 - top2_acc: 0.6975 - top3_acc: 0.7538 - val_loss: 0.1591 - val_acc: 0.9500 - val_top1_acc: 0.2350 - val_top2_acc: 0.7300 - val_top3_acc: 0.7450
# Epoch 59/100
# 25/25 [==============================] - 166s 7s/step - loss: 0.0750 - acc: 0.9800 - top1_acc: 0.2550 - top2_acc: 0.7237 - top3_acc: 0.7575 - val_loss: 1.5257 - val_acc: 0.6800 - val_top1_acc: 0.1650 - val_top2_acc: 0.8150 - val_top3_acc: 0.9350
# Epoch 60/100
# 25/25 [==============================] - 165s 7s/step - loss: 0.0677 - acc: 0.9800 - top1_acc: 0.2537 - top2_acc: 0.7400 - top3_acc: 0.7575 - val_loss: 0.1216 - val_acc: 0.9800 - val_top1_acc: 0.2450 - val_top2_acc: 0.7250 - val_top3_acc: 0.7300
# Epoch 61/100
# 25/25 [==============================] - 164s 7s/step - loss: 0.0255 - acc: 0.9950 - top1_acc: 0.2537 - top2_acc: 0.7362 - top3_acc: 0.7563 - val_loss: 0.0296 - val_acc: 0.9900 - val_top1_acc: 0.2450 - val_top2_acc: 0.7200 - val_top3_acc: 0.7300
# Epoch 62/100
# 25/25 [==============================] - 164s 7s/step - loss: 0.0261 - acc: 0.9900 - top1_acc: 0.2525 - top2_acc: 0.7325 - top3_acc: 0.7550 - val_loss: 0.0419 - val_acc: 0.9850 - val_top1_acc: 0.2500 - val_top2_acc: 0.7100 - val_top3_acc: 0.7250
# Epoch 63/100
# 25/25 [==============================] - 164s 7s/step - loss: 0.0211 - acc: 0.9925 - top1_acc: 0.2475 - top2_acc: 0.7287 - top3_acc: 0.7513 - val_loss: 0.2890 - val_acc: 0.9350 - val_top1_acc: 0.3050 - val_top2_acc: 0.7200 - val_top3_acc: 0.7300
# Epoch 64/100
# 25/25 [==============================] - 164s 7s/step - loss: 0.0741 - acc: 0.9762 - top1_acc: 0.2550 - top2_acc: 0.7088 - top3_acc: 0.7525 - val_loss: 6.0078 - val_acc: 0.4350 - val_top1_acc: 0.0650 - val_top2_acc: 0.4100 - val_top3_acc: 0.9550
# Epoch 65/100
# 25/25 [==============================] - 166s 7s/step - loss: 0.0793 - acc: 0.9762 - top1_acc: 0.2562 - top2_acc: 0.7100 - top3_acc: 0.7613 - val_loss: 0.3425 - val_acc: 0.9450 - val_top1_acc: 0.2600 - val_top2_acc: 0.6800 - val_top3_acc: 0.7500
# Epoch 66/100
# 25/25 [==============================] - 165s 7s/step - loss: 0.0268 - acc: 0.9900 - top1_acc: 0.2500 - top2_acc: 0.7100 - top3_acc: 0.7462 - val_loss: 1.3028 - val_acc: 0.8500 - val_top1_acc: 0.2050 - val_top2_acc: 0.5400 - val_top3_acc: 0.6500
# Epoch 67/100
# 25/25 [==============================] - 167s 7s/step - loss: 0.0172 - acc: 0.9925 - top1_acc: 0.2488 - top2_acc: 0.7350 - top3_acc: 0.7525 - val_loss: 0.3338 - val_acc: 0.9650 - val_top1_acc: 0.2400 - val_top2_acc: 0.6000 - val_top3_acc: 0.6950
# Epoch 68/100
# 25/25 [==============================] - 168s 7s/step - loss: 0.0325 - acc: 0.9912 - top1_acc: 0.2575 - top2_acc: 0.7400 - top3_acc: 0.7538 - val_loss: 0.1093 - val_acc: 0.9700 - val_top1_acc: 0.2500 - val_top2_acc: 0.7250 - val_top3_acc: 0.7300
# Epoch 69/100
# 25/25 [==============================] - 171s 7s/step - loss: 0.0606 - acc: 0.9787 - top1_acc: 0.2525 - top2_acc: 0.7287 - top3_acc: 0.7563 - val_loss: 0.8992 - val_acc: 0.7550 - val_top1_acc: 0.4650 - val_top2_acc: 0.7950 - val_top3_acc: 0.8350
# Epoch 70/100
# 25/25 [==============================] - 172s 7s/step - loss: 0.0786 - acc: 0.9750 - top1_acc: 0.2488 - top2_acc: 0.7188 - top3_acc: 0.7550 - val_loss: 0.3239 - val_acc: 0.8900 - val_top1_acc: 0.3250 - val_top2_acc: 0.7500 - val_top3_acc: 0.8150
# Epoch 71/100
# 25/25 [==============================] - 167s 7s/step - loss: 0.0596 - acc: 0.9775 - top1_acc: 0.2562 - top2_acc: 0.6800 - top3_acc: 0.7525 - val_loss: 0.2394 - val_acc: 0.9150 - val_top1_acc: 0.2250 - val_top2_acc: 0.6500 - val_top3_acc: 0.7900
# Epoch 72/100
# 25/25 [==============================] - 164s 7s/step - loss: 0.0460 - acc: 0.9837 - top1_acc: 0.2525 - top2_acc: 0.6850 - top3_acc: 0.7600 - val_loss: 0.3129 - val_acc: 0.9400 - val_top1_acc: 0.1950 - val_top2_acc: 0.6200 - val_top3_acc: 0.7250
# Epoch 73/100
# 25/25 [==============================] - 164s 7s/step - loss: 0.0915 - acc: 0.9700 - top1_acc: 0.2525 - top2_acc: 0.6850 - top3_acc: 0.7563 - val_loss: 2.3917 - val_acc: 0.6200 - val_top1_acc: 0.0450 - val_top2_acc: 0.5800 - val_top3_acc: 0.8200
# Epoch 74/100
# 25/25 [==============================] - 164s 7s/step - loss: 0.0323 - acc: 0.9912 - top1_acc: 0.2500 - top2_acc: 0.6963 - top3_acc: 0.7487 - val_loss: 7.3447 - val_acc: 0.4500 - val_top1_acc: 0.2350 - val_top2_acc: 0.7650 - val_top3_acc: 1.0000
# Epoch 75/100
# 25/25 [==============================] - 164s 7s/step - loss: 0.0367 - acc: 0.9900 - top1_acc: 0.2537 - top2_acc: 0.6675 - top3_acc: 0.7437 - val_loss: 0.2727 - val_acc: 0.9650 - val_top1_acc: 0.2700 - val_top2_acc: 0.6800 - val_top3_acc: 0.7250
# Epoch 76/100
# 25/25 [==============================] - 165s 7s/step - loss: 0.0618 - acc: 0.9850 - top1_acc: 0.2575 - top2_acc: 0.7100 - top3_acc: 0.7538 - val_loss: 0.4710 - val_acc: 0.8550 - val_top1_acc: 0.1350 - val_top2_acc: 0.6750 - val_top3_acc: 0.7200
# Epoch 77/100
# 25/25 [==============================] - 164s 7s/step - loss: 0.0464 - acc: 0.9862 - top1_acc: 0.2488 - top2_acc: 0.7325 - top3_acc: 0.7538 - val_loss: 0.4769 - val_acc: 0.9150 - val_top1_acc: 0.3150 - val_top2_acc: 0.7050 - val_top3_acc: 0.7250
# Epoch 78/100
# 25/25 [==============================] - 165s 7s/step - loss: 0.0149 - acc: 0.9962 - top1_acc: 0.2525 - top2_acc: 0.7262 - top3_acc: 0.7550 - val_loss: 5.5409 - val_acc: 0.6500 - val_top1_acc: 0.2600 - val_top2_acc: 0.8650 - val_top3_acc: 0.9900
# Epoch 79/100
# 25/25 [==============================] - 164s 7s/step - loss: 0.0125 - acc: 0.9937 - top1_acc: 0.2525 - top2_acc: 0.7225 - top3_acc: 0.7563 - val_loss: 0.0908 - val_acc: 0.9800 - val_top1_acc: 0.2400 - val_top2_acc: 0.6800 - val_top3_acc: 0.7200
# Epoch 80/100
# 25/25 [==============================] - 165s 7s/step - loss: 0.0513 - acc: 0.9825 - top1_acc: 0.2562 - top2_acc: 0.7262 - top3_acc: 0.7550 - val_loss: 0.8863 - val_acc: 0.8250 - val_top1_acc: 0.2300 - val_top2_acc: 0.6750 - val_top3_acc: 0.8350
# Epoch 81/100
# 25/25 [==============================] - 164s 7s/step - loss: 0.0376 - acc: 0.9887 - top1_acc: 0.2500 - top2_acc: 0.7237 - top3_acc: 0.7550 - val_loss: 0.4149 - val_acc: 0.8850 - val_top1_acc: 0.1450 - val_top2_acc: 0.5150 - val_top3_acc: 0.7050
# Epoch 82/100
# 25/25 [==============================] - 167s 7s/step - loss: 0.0660 - acc: 0.9837 - top1_acc: 0.2562 - top2_acc: 0.7188 - top3_acc: 0.7575 - val_loss: 2.2087 - val_acc: 0.7000 - val_top1_acc: 0.2000 - val_top2_acc: 0.5500 - val_top3_acc: 0.8800
# Epoch 83/100
# 25/25 [==============================] - 170s 7s/step - loss: 0.0437 - acc: 0.9862 - top1_acc: 0.2537 - top2_acc: 0.7188 - top3_acc: 0.7538 - val_loss: 0.3639 - val_acc: 0.9300 - val_top1_acc: 0.1900 - val_top2_acc: 0.7000 - val_top3_acc: 0.7200
# Epoch 84/100
# 25/25 [==============================] - 171s 7s/step - loss: 0.0340 - acc: 0.9875 - top1_acc: 0.2537 - top2_acc: 0.7375 - top3_acc: 0.7525 - val_loss: 0.1826 - val_acc: 0.9500 - val_top1_acc: 0.2650 - val_top2_acc: 0.7100 - val_top3_acc: 0.7350
# Epoch 85/100
# 25/25 [==============================] - 169s 7s/step - loss: 0.0323 - acc: 0.9887 - top1_acc: 0.2488 - top2_acc: 0.7275 - top3_acc: 0.7538 - val_loss: 0.1758 - val_acc: 0.9650 - val_top1_acc: 0.2350 - val_top2_acc: 0.6750 - val_top3_acc: 0.7100
# Epoch 86/100
# 25/25 [==============================] - 164s 7s/step - loss: 0.0229 - acc: 0.9912 - top1_acc: 0.2562 - top2_acc: 0.7412 - top3_acc: 0.7525 - val_loss: 0.3211 - val_acc: 0.9200 - val_top1_acc: 0.2700 - val_top2_acc: 0.7250 - val_top3_acc: 0.8050
# Epoch 87/100
# 25/25 [==============================] - 166s 7s/step - loss: 0.0171 - acc: 0.9925 - top1_acc: 0.2537 - top2_acc: 0.7412 - top3_acc: 0.7563 - val_loss: 2.3772 - val_acc: 0.6600 - val_top1_acc: 0.3400 - val_top2_acc: 0.7800 - val_top3_acc: 0.8800
# Epoch 88/100
# 25/25 [==============================] - 164s 7s/step - loss: 0.0336 - acc: 0.9900 - top1_acc: 0.2512 - top2_acc: 0.7500 - top3_acc: 0.7563 - val_loss: 0.1111 - val_acc: 0.9600 - val_top1_acc: 0.2650 - val_top2_acc: 0.7150 - val_top3_acc: 0.7200
# Epoch 89/100
# 25/25 [==============================] - 167s 7s/step - loss: 0.0257 - acc: 0.9950 - top1_acc: 0.2550 - top2_acc: 0.7287 - top3_acc: 0.7550 - val_loss: 0.0796 - val_acc: 0.9850 - val_top1_acc: 0.2500 - val_top2_acc: 0.7200 - val_top3_acc: 0.7950
# Epoch 90/100
# 25/25 [==============================] - 165s 7s/step - loss: 0.0093 - acc: 0.9975 - top1_acc: 0.2525 - top2_acc: 0.7425 - top3_acc: 0.7538 - val_loss: 0.1182 - val_acc: 0.9700 - val_top1_acc: 0.2650 - val_top2_acc: 0.7200 - val_top3_acc: 0.7200
# Epoch 91/100
# 25/25 [==============================] - 165s 7s/step - loss: 0.0168 - acc: 0.9975 - top1_acc: 0.2537 - top2_acc: 0.7312 - top3_acc: 0.7513 - val_loss: 0.0918 - val_acc: 0.9850 - val_top1_acc: 0.2450 - val_top2_acc: 0.7050 - val_top3_acc: 0.7200
# Epoch 92/100
# 25/25 [==============================] - 165s 7s/step - loss: 0.0282 - acc: 0.9912 - top1_acc: 0.2500 - top2_acc: 0.7200 - top3_acc: 0.7550 - val_loss: 0.2807 - val_acc: 0.9600 - val_top1_acc: 0.2150 - val_top2_acc: 0.5900 - val_top3_acc: 0.7150
# Epoch 93/100
# 25/25 [==============================] - 164s 7s/step - loss: 0.0474 - acc: 0.9862 - top1_acc: 0.2537 - top2_acc: 0.7075 - top3_acc: 0.7450 - val_loss: 0.0851 - val_acc: 0.9650 - val_top1_acc: 0.2300 - val_top2_acc: 0.7050 - val_top3_acc: 0.7200
# Epoch 94/100
# 25/25 [==============================] - 165s 7s/step - loss: 0.0212 - acc: 0.9937 - top1_acc: 0.2525 - top2_acc: 0.7325 - top3_acc: 0.7550 - val_loss: 0.1001 - val_acc: 0.9600 - val_top1_acc: 0.2000 - val_top2_acc: 0.6850 - val_top3_acc: 0.7100
# Epoch 95/100
# 25/25 [==============================] - 164s 7s/step - loss: 0.0120 - acc: 0.9950 - top1_acc: 0.2500 - top2_acc: 0.7287 - top3_acc: 0.7500 - val_loss: 0.1032 - val_acc: 0.9600 - val_top1_acc: 0.2400 - val_top2_acc: 0.6250 - val_top3_acc: 0.7250
# Epoch 96/100
# 25/25 [==============================] - 167s 7s/step - loss: 0.0132 - acc: 0.9962 - top1_acc: 0.2562 - top2_acc: 0.6125 - top3_acc: 0.7462 - val_loss: 0.1772 - val_acc: 0.9550 - val_top1_acc: 0.2000 - val_top2_acc: 0.4800 - val_top3_acc: 0.7250
# Epoch 97/100
# 25/25 [==============================] - 167s 7s/step - loss: 0.0058 - acc: 1.0000 - top1_acc: 0.2525 - top2_acc: 0.6888 - top3_acc: 0.7500 - val_loss: 0.0915 - val_acc: 0.9800 - val_top1_acc: 0.2550 - val_top2_acc: 0.7050 - val_top3_acc: 0.7200
# Epoch 98/100
# 25/25 [==============================] - 172s 7s/step - loss: 0.0415 - acc: 0.9887 - top1_acc: 0.2575 - top2_acc: 0.5537 - top3_acc: 0.7063 - val_loss: 0.4847 - val_acc: 0.8900 - val_top1_acc: 0.2850 - val_top2_acc: 0.5450 - val_top3_acc: 0.6500
# Epoch 99/100
# 25/25 [==============================] - 171s 7s/step - loss: 0.0945 - acc: 0.9725 - top1_acc: 0.2500 - top2_acc: 0.6338 - top3_acc: 0.7212 - val_loss: 0.1218 - val_acc: 0.9600 - val_top1_acc: 0.2250 - val_top2_acc: 0.6550 - val_top3_acc: 0.7150
# Epoch 100/100
# 25/25 [==============================] - 165s 7s/step - loss: 0.0420 - acc: 0.9875 - top1_acc: 0.2550 - top2_acc: 0.7200 - top3_acc: 0.7513 - val_loss: 0.4045 - val_acc: 0.9250 - val_top1_acc: 0.2450 - val_top2_acc: 0.7100 - val_top3_acc: 0.7950
# Maximal validation accuracy: 99.00%

# %% [markdown]
# ## Self-supervised model for contrastive pretraining

# %%
# Define the contrastive model with model-subclassing
class ContrastiveModel(keras.Model):
    """This is where the teacher net magic happens. Here we're instantiating a class to design a contrastive net.
    In this class, we use temperature, the augmenter defined above, and the encoder (resnet model) under two different
    outputs. 
    
    Training step uses: Non-linear MLP as projection head:
        Here is where we train the weights of the resnet. In the training step,
        we call the image database input (named unlabeled) and augment it twice (in 2 different ways).
        These positive pairs (A/B) are pushed through their own projection heads (1,2) and a
        contrastive loss is calculated. Weights are updated during the step as training = True for our encoder.
        
    Test step uses: Linear Probe:
        linear probe takes an input of width (final layer of our resnet) and uses a FC layer to step
        back down to 4 should eventually change this n_classes and use n_classes as either an input or
        global set variable. No weight updates occur during the test call, as training = False for our encoder"""
    def __init__(self):
        super().__init__()

        self.temperature = temperature
        self.contrastive_augmenter = get_augmenter(**contrastive_augmentation)
        self.classification_augmenter = get_augmenter(**classification_augmentation)
        self.encoder =  get_resnet_encoder(resnet50, labeled_train_dataset, image_size, image_channels, width)
        # Non-linear MLP as projection head - Note, output is of width width. This is okay as we use matrix calculations to reduce the size to a single loss value per step
        self.projection_head = keras.Sequential(
            [
                keras.Input(shape=(width,)),
                layers.Dense(width, activation="relu"),
                layers.Dense(width),
            ],
            name="projection_head",
        )
        # Single dense layer for linear probing
        self.linear_probe = keras.Sequential(
            [layers.Input(shape=(width,)), layers.Dense(4)], name="linear_probe"
        )

        self.encoder.summary()
        self.projection_head.summary()
        self.linear_probe.summary()

    def compile(self, contrastive_optimizer, probe_optimizer, **kwargs):
        """defines the compile for the model, here we call the standard compile method using super()
        and we have compile details for both the probe (test) and the contrastive steps (train)"""
        super().compile(**kwargs)

        self.contrastive_optimizer = contrastive_optimizer
        self.probe_optimizer = probe_optimizer

        # self.contrastive_loss will be defined as a method
        self.probe_loss = keras.losses.SparseCategoricalCrossentropy(from_logits=True)

        self.contrastive_loss_tracker = keras.metrics.Mean(name="c_loss")
        self.contrastive_accuracy = keras.metrics.SparseCategoricalAccuracy(
            name="c_acc"
        )
        self.probe_loss_tracker = keras.metrics.Mean(name="p_loss")
        self.probe_accuracy = keras.metrics.SparseCategoricalAccuracy(name="p_acc")

    @property
    def metrics(self):
        """These are metrics we want to print and carry through our gradient tape"""
        return [
            self.contrastive_loss_tracker,
            self.contrastive_accuracy,
            self.probe_loss_tracker,
            self.probe_accuracy,
        ]

    def contrastive_loss(self, projections_1, projections_2):
        """The loss function for contrastive loss, executed during the train step between positive pairs"""
        # InfoNCE loss (information noise-contrastive estimation)
        # NT-Xent loss (normalized temperature-scaled cross entropy)

        # Cosine similarity: the dot product of the l2-normalized feature vectors
        projections_1 = tf.math.l2_normalize(projections_1, axis=1)
        projections_2 = tf.math.l2_normalize(projections_2, axis=1)
        similarities = (
            tf.matmul(projections_1, projections_2, transpose_b=True) / self.temperature
        )

        # The similarity between the representations of two augmented views of the
        # same image should be higher than their similarity with other views
        batch_size = tf.shape(projections_1)[0]
        contrastive_labels = tf.range(batch_size)
        self.contrastive_accuracy.update_state(contrastive_labels, similarities)
        self.contrastive_accuracy.update_state(
            contrastive_labels, tf.transpose(similarities)
        )

        # The temperature-scaled similarities are used as logits for cross-entropy
        # a symmetrized version of the loss is used here
        loss_1_2 = keras.losses.sparse_categorical_crossentropy(
            contrastive_labels, similarities, from_logits=True
        )
        loss_2_1 = keras.losses.sparse_categorical_crossentropy(
            contrastive_labels, tf.transpose(similarities), from_logits=True
        )
        return (loss_1_2 + loss_2_1) / 2

    def train_step(self, data):
        (unlabeled_images, _), (labeled_images, labels) = data

        # Both labeled and unlabeled images are used, without labels
        images = tf.concat((unlabeled_images, labeled_images), axis=0)
        # Each image is augmented twice, differently
        augmented_images_1 = self.contrastive_augmenter(images, training=True)
        augmented_images_2 = self.contrastive_augmenter(images, training=True)
        with tf.GradientTape() as tape:
            features_1 = self.encoder(augmented_images_1, training=True)
            features_2 = self.encoder(augmented_images_2, training=True)
            # The representations are passed through a projection mlp
            projections_1 = self.projection_head(features_1, training=True)
            projections_2 = self.projection_head(features_2, training=True)
            contrastive_loss = self.contrastive_loss(projections_1, projections_2)
        gradients = tape.gradient(
            contrastive_loss,
            self.encoder.trainable_weights + self.projection_head.trainable_weights,
        )
        self.contrastive_optimizer.apply_gradients(
            zip(
                gradients,
                self.encoder.trainable_weights + self.projection_head.trainable_weights,
            )
        )
        self.contrastive_loss_tracker.update_state(contrastive_loss)

        # Labels are only used in evalutation for an on-the-fly logistic regression
        preprocessed_images = self.classification_augmenter(
            labeled_images, training=True
        )
        with tf.GradientTape() as tape:
            # the encoder is used in inference mode here to avoid regularization
            # and updating the batch normalization paramers if they are used
            features = self.encoder(preprocessed_images, training=False)
            class_logits = self.linear_probe(features, training=True)
            probe_loss = self.probe_loss(labels, class_logits)
        gradients = tape.gradient(probe_loss, self.linear_probe.trainable_weights)
        self.probe_optimizer.apply_gradients(
            zip(gradients, self.linear_probe.trainable_weights)
        )
        self.probe_loss_tracker.update_state(probe_loss)
        self.probe_accuracy.update_state(labels, class_logits)

        return {m.name: m.result() for m in self.metrics}

    def test_step(self, data):
        labeled_images, labels = data

        # For testing the components are used with a training=False flag
        preprocessed_images = self.classification_augmenter(
            labeled_images, training=False
        )
        features = self.encoder(preprocessed_images, training=False)
        class_logits = self.linear_probe(features, training=False)
        probe_loss = self.probe_loss(labels, class_logits)
        self.probe_loss_tracker.update_state(probe_loss)
        self.probe_accuracy.update_state(labels, class_logits)

        # Only the probe metrics are logged at test time
        return {m.name: m.result() for m in self.metrics[2:]}


# Contrastive pretraining
pretraining_model = ContrastiveModel() #calls the class, which has the inits in it 
pretraining_model.compile(
    contrastive_optimizer=keras.optimizers.Adam(),
    probe_optimizer=keras.optimizers.Adam(),
)
#compiles, note that metrics are assigned as a property and do not need to be specified.
#Also note we have 2 optimizers, 1 for the test and 1 for the train step

pretraining_history = pretraining_model.fit(
    train_dataset, epochs=num_epochs, validation_data=test_dataset
)
print(
    "Maximal validation accuracy: {:.2f}%".format(
        max(pretraining_history.history["val_p_acc"]) * 100
    )
)
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_11 (InputLayer)       [(None, 224, 224, 3)]     0
#
#  resnet50 (Functional)       (None, 7, 7, 2048)        23587712
#
#  global_average_pooling2d_2   (None, 2048)             0
#  (GlobalAveragePooling2D)
#
#  dense_3 (Dense)             (None, 128)               262272
#
# =================================================================
# Total params: 23,849,984
# Trainable params: 23,796,864
# Non-trainable params: 53,120
# _________________________________________________________________
# Model: "projection_head"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_4 (Dense)             (None, 128)               16512
#
#  dense_5 (Dense)             (None, 128)               16512
#
# =================================================================
# Total params: 33,024
# Trainable params: 33,024
# Non-trainable params: 0
# _________________________________________________________________
# Model: "linear_probe"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_6 (Dense)             (None, 4)                 516
#
# =================================================================
# Total params: 516
# Trainable params: 516
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3
# 25/25 [==============================] - 659s 26s/step - c_loss: 3.3985 - c_acc: 0.1150 - p_loss: 6.5967 - p_acc: 0.2550 - val_p_loss: 12.2250 - val_p_acc: 0.2900
# Epoch 2/100
# 25/25 [==============================] - 634s 25s/step - c_loss: 3.0036 - c_acc: 0.1719 - p_loss: 5.0076 - p_acc: 0.2713 - val_p_loss: 2.9091 - val_p_acc: 0.2600
# Epoch 3/100
# 25/25 [==============================] - 664s 27s/step - c_loss: 2.8342 - c_acc: 0.2456 - p_loss: 3.3624 - p_acc: 0.3113 - val_p_loss: 8.2426 - val_p_acc: 0.2750
# Epoch 4/100
# 25/25 [==============================] - 665s 27s/step - c_loss: 2.5056 - c_acc: 0.3116 - p_loss: 7.3155 - p_acc: 0.3663 - val_p_loss: 13.2431 - val_p_acc: 0.2900
# Epoch 5/100
# 25/25 [==============================] - 652s 26s/step - c_loss: 2.2318 - c_acc: 0.3922 - p_loss: 7.4341 - p_acc: 0.3225 - val_p_loss: 15.4081 - val_p_acc: 0.3900
# Epoch 6/100
# 25/25 [==============================] - 641s 26s/step - c_loss: 2.1326 - c_acc: 0.4119 - p_loss: 6.0895 - p_acc: 0.3100 - val_p_loss: 3.6107 - val_p_acc: 0.5350
# Epoch 7/100
# 25/25 [==============================] - 656s 26s/step - c_loss: 1.9370 - c_acc: 0.4825 - p_loss: 3.6240 - p_acc: 0.5100 - val_p_loss: 4.9465 - val_p_acc: 0.4450
# Epoch 8/100
# 25/25 [==============================] - 639s 25s/step - c_loss: 1.8518 - c_acc: 0.4916 - p_loss: 2.1621 - p_acc: 0.5525 - val_p_loss: 2.7213 - val_p_acc: 0.3900
# Epoch 9/100
# 25/25 [==============================] - 646s 26s/step - c_loss: 1.7095 - c_acc: 0.5306 - p_loss: 2.9670 - p_acc: 0.4125 - val_p_loss: 2.7875 - val_p_acc: 0.5600
# Epoch 10/100
# 25/25 [==============================] - 649s 26s/step - c_loss: 1.5385 - c_acc: 0.5844 - p_loss: 2.5315 - p_acc: 0.5013 - val_p_loss: 2.4039 - val_p_acc: 0.4950
# Epoch 11/100
# 25/25 [==============================] - 691s 28s/step - c_loss: 1.3589 - c_acc: 0.6356 - p_loss: 1.3691 - p_acc: 0.6150 - val_p_loss: 2.6674 - val_p_acc: 0.4150
# Epoch 12/100
# 25/25 [==============================] - 634s 25s/step - c_loss: 1.3393 - c_acc: 0.6322 - p_loss: 1.4163 - p_acc: 0.6625 - val_p_loss: 1.2708 - val_p_acc: 0.6150
# Epoch 13/100
# 25/25 [==============================] - 674s 27s/step - c_loss: 1.2969 - c_acc: 0.6525 - p_loss: 1.6792 - p_acc: 0.6650 - val_p_loss: 2.1594 - val_p_acc: 0.5050
# Epoch 14/100
# 25/25 [==============================] - 648s 26s/step - c_loss: 1.2031 - c_acc: 0.6622 - p_loss: 1.2970 - p_acc: 0.6712 - val_p_loss: 1.3394 - val_p_acc: 0.7100
# Epoch 15/100
# 25/25 [==============================] - 648s 26s/step - c_loss: 1.1512 - c_acc: 0.7038 - p_loss: 0.8108 - p_acc: 0.7475 - val_p_loss: 1.2710 - val_p_acc: 0.7150
# Epoch 16/100
# 25/25 [==============================] - 652s 26s/step - c_loss: 1.2086 - c_acc: 0.6825 - p_loss: 0.7875 - p_acc: 0.7600 - val_p_loss: 1.5299 - val_p_acc: 0.6100
# Epoch 17/100
# 25/25 [==============================] - 628s 25s/step - c_loss: 1.0962 - c_acc: 0.7013 - p_loss: 0.6394 - p_acc: 0.8000 - val_p_loss: 0.9038 - val_p_acc: 0.7600
# Epoch 18/100
# 25/25 [==============================] - 675s 27s/step - c_loss: 1.1050 - c_acc: 0.7088 - p_loss: 2.4822 - p_acc: 0.6550 - val_p_loss: 2.4820 - val_p_acc: 0.6700
# Epoch 19/100
# 25/25 [==============================] - 657s 26s/step - c_loss: 0.9501 - c_acc: 0.7525 - p_loss: 1.8344 - p_acc: 0.6875 - val_p_loss: 1.3364 - val_p_acc: 0.6850
# Epoch 20/100
# 25/25 [==============================] - 632s 25s/step - c_loss: 0.8994 - c_acc: 0.7713 - p_loss: 0.7369 - p_acc: 0.7837 - val_p_loss: 0.9273 - val_p_acc: 0.7850
# Epoch 21/100
# 25/25 [==============================] - 649s 26s/step - c_loss: 0.9500 - c_acc: 0.7534 - p_loss: 0.7648 - p_acc: 0.7725 - val_p_loss: 0.6703 - val_p_acc: 0.8100
# Epoch 22/100
# 25/25 [==============================] - 690s 28s/step - c_loss: 0.9604 - c_acc: 0.7563 - p_loss: 0.6149 - p_acc: 0.8200 - val_p_loss: 1.6949 - val_p_acc: 0.6050
# Epoch 23/100
# 25/25 [==============================] - 642s 26s/step - c_loss: 0.9712 - c_acc: 0.7506 - p_loss: 0.9073 - p_acc: 0.7825 - val_p_loss: 0.9870 - val_p_acc: 0.7500
# Epoch 24/100
# 25/25 [==============================] - 654s 26s/step - c_loss: 0.8815 - c_acc: 0.7722 - p_loss: 0.8082 - p_acc: 0.8012 - val_p_loss: 0.7922 - val_p_acc: 0.8050
# Epoch 25/100
# 25/25 [==============================] - 650s 26s/step - c_loss: 0.8189 - c_acc: 0.7812 - p_loss: 0.6355 - p_acc: 0.8163 - val_p_loss: 0.6629 - val_p_acc: 0.8200
# Epoch 26/100
# 25/25 [==============================] - 655s 26s/step - c_loss: 0.9506 - c_acc: 0.7544 - p_loss: 0.6717 - p_acc: 0.7950 - val_p_loss: 1.0128 - val_p_acc: 0.7750
# Epoch 27/100
# 25/25 [==============================] - 650s 26s/step - c_loss: 0.8598 - c_acc: 0.7806 - p_loss: 0.7147 - p_acc: 0.8125 - val_p_loss: 0.6564 - val_p_acc: 0.8000
# Epoch 28/100
# 25/25 [==============================] - 642s 26s/step - c_loss: 0.8710 - c_acc: 0.7816 - p_loss: 0.6324 - p_acc: 0.8288 - val_p_loss: 1.5429 - val_p_acc: 0.7350
# Epoch 29/100
# 25/25 [==============================] - 662s 26s/step - c_loss: 0.8435 - c_acc: 0.7819 - p_loss: 1.3095 - p_acc: 0.7525 - val_p_loss: 0.6663 - val_p_acc: 0.8450
# Epoch 30/100
# 25/25 [==============================] - 645s 26s/step - c_loss: 0.8225 - c_acc: 0.7847 - p_loss: 0.5435 - p_acc: 0.8350 - val_p_loss: 0.9722 - val_p_acc: 0.7100
# Epoch 31/100
# 25/25 [==============================] - 638s 25s/step - c_loss: 0.8357 - c_acc: 0.7847 - p_loss: 1.0207 - p_acc: 0.7462 - val_p_loss: 0.9560 - val_p_acc: 0.7350
# Epoch 32/100
# 25/25 [==============================] - 639s 25s/step - c_loss: 0.7640 - c_acc: 0.8112 - p_loss: 0.8730 - p_acc: 0.7650 - val_p_loss: 0.3166 - val_p_acc: 0.8950
# Epoch 33/100
# 25/25 [==============================] - 694s 28s/step - c_loss: 0.6675 - c_acc: 0.8391 - p_loss: 0.5886 - p_acc: 0.8163 - val_p_loss: 0.8663 - val_p_acc: 0.7200
# Epoch 34/100
# 25/25 [==============================] - 629s 25s/step - c_loss: 0.7178 - c_acc: 0.8191 - p_loss: 0.6949 - p_acc: 0.7825 - val_p_loss: 0.4943 - val_p_acc: 0.8650
# Epoch 35/100
# 25/25 [==============================] - 647s 26s/step - c_loss: 0.6780 - c_acc: 0.8269 - p_loss: 0.6285 - p_acc: 0.8087 - val_p_loss: 0.4054 - val_p_acc: 0.8500
# Epoch 36/100
# 25/25 [==============================] - 660s 26s/step - c_loss: 0.7172 - c_acc: 0.8263 - p_loss: 0.4859 - p_acc: 0.8388 - val_p_loss: 0.7037 - val_p_acc: 0.8000
# Epoch 37/100
# 25/25 [==============================] - 679s 27s/step - c_loss: 0.6517 - c_acc: 0.8363 - p_loss: 0.5965 - p_acc: 0.8288 - val_p_loss: 0.5471 - val_p_acc: 0.8500
# Epoch 38/100
# 25/25 [==============================] - 643s 26s/step - c_loss: 0.6896 - c_acc: 0.8159 - p_loss: 0.5533 - p_acc: 0.8375 - val_p_loss: 0.5545 - val_p_acc: 0.8150
# Epoch 39/100
# 25/25 [==============================] - 629s 25s/step - c_loss: 0.6286 - c_acc: 0.8391 - p_loss: 0.5150 - p_acc: 0.8425 - val_p_loss: 0.5776 - val_p_acc: 0.8400
# Epoch 40/100
# 25/25 [==============================] - 652s 26s/step - c_loss: 0.6176 - c_acc: 0.8397 - p_loss: 0.6304 - p_acc: 0.8112 - val_p_loss: 0.8454 - val_p_acc: 0.8000
# Epoch 41/100
# 25/25 [==============================] - 660s 26s/step - c_loss: 0.6319 - c_acc: 0.8322 - p_loss: 0.6288 - p_acc: 0.8350 - val_p_loss: 0.6316 - val_p_acc: 0.8050
# Epoch 42/100
# 25/25 [==============================] - 629s 25s/step - c_loss: 0.7026 - c_acc: 0.8231 - p_loss: 0.4962 - p_acc: 0.8487 - val_p_loss: 0.4461 - val_p_acc: 0.8550
# Epoch 43/100
# 25/25 [==============================] - 620s 25s/step - c_loss: 0.6663 - c_acc: 0.8363 - p_loss: 0.9065 - p_acc: 0.7987 - val_p_loss: 2.0723 - val_p_acc: 0.5800
# Epoch 44/100
# 25/25 [==============================] - 662s 27s/step - c_loss: 0.6203 - c_acc: 0.8472 - p_loss: 0.6120 - p_acc: 0.8200 - val_p_loss: 0.3888 - val_p_acc: 0.9000
# Epoch 45/100
# 25/25 [==============================] - 618s 24s/step - c_loss: 0.6219 - c_acc: 0.8344 - p_loss: 0.5577 - p_acc: 0.8662 - val_p_loss: 0.9414 - val_p_acc: 0.7950
# Epoch 46/100
# 25/25 [==============================] - 621s 25s/step - c_loss: 0.5730 - c_acc: 0.8559 - p_loss: 0.6382 - p_acc: 0.8200 - val_p_loss: 0.7723 - val_p_acc: 0.8200
# Epoch 47/100
# 25/25 [==============================] - 629s 25s/step - c_loss: 0.6040 - c_acc: 0.8481 - p_loss: 0.6255 - p_acc: 0.8313 - val_p_loss: 0.5052 - val_p_acc: 0.8800
# Epoch 48/100
# 25/25 [==============================] - 677s 27s/step - c_loss: 0.5919 - c_acc: 0.8544 - p_loss: 0.5568 - p_acc: 0.8500 - val_p_loss: 0.6100 - val_p_acc: 0.8250
# Epoch 49/100
# 25/25 [==============================] - 626s 25s/step - c_loss: 0.5566 - c_acc: 0.8619 - p_loss: 0.6318 - p_acc: 0.8475 - val_p_loss: 0.3909 - val_p_acc: 0.8800
# Epoch 50/100
# 25/25 [==============================] - 629s 25s/step - c_loss: 0.5392 - c_acc: 0.8681 - p_loss: 0.7774 - p_acc: 0.8250 - val_p_loss: 1.6714 - val_p_acc: 0.7050
# Epoch 51/100
# 25/25 [==============================] - 609s 24s/step - c_loss: 0.5609 - c_acc: 0.8581 - p_loss: 0.5816 - p_acc: 0.8612 - val_p_loss: 0.5202 - val_p_acc: 0.8750
# Epoch 52/100
# 25/25 [==============================] - 669s 27s/step - c_loss: 0.5673 - c_acc: 0.8634 - p_loss: 0.4766 - p_acc: 0.9000 - val_p_loss: 0.4552 - val_p_acc: 0.8550
# Epoch 53/100
# 25/25 [==============================] - 632s 25s/step - c_loss: 0.5038 - c_acc: 0.8737 - p_loss: 0.2918 - p_acc: 0.9187 - val_p_loss: 0.4585 - val_p_acc: 0.8600
# Epoch 54/100
# 25/25 [==============================] - 632s 25s/step - c_loss: 0.5160 - c_acc: 0.8712 - p_loss: 0.5630 - p_acc: 0.8425 - val_p_loss: 0.4761 - val_p_acc: 0.8700
# Epoch 55/100
# 25/25 [==============================] - 622s 25s/step - c_loss: 0.5233 - c_acc: 0.8719 - p_loss: 0.5259 - p_acc: 0.8800 - val_p_loss: 0.3482 - val_p_acc: 0.9300
# Epoch 56/100
# 25/25 [==============================] - 654s 26s/step - c_loss: 0.4862 - c_acc: 0.8850 - p_loss: 0.4901 - p_acc: 0.8675 - val_p_loss: 0.5351 - val_p_acc: 0.8750
# Epoch 57/100
# 25/25 [==============================] - 629s 25s/step - c_loss: 0.5083 - c_acc: 0.8731 - p_loss: 0.4317 - p_acc: 0.8700 - val_p_loss: 0.6423 - val_p_acc: 0.8300
# Epoch 58/100
# 25/25 [==============================] - 620s 25s/step - c_loss: 0.4481 - c_acc: 0.8950 - p_loss: 0.4080 - p_acc: 0.8800 - val_p_loss: 0.2543 - val_p_acc: 0.9250
# Epoch 59/100
# 25/25 [==============================] - 618s 25s/step - c_loss: 0.4993 - c_acc: 0.8750 - p_loss: 0.3177 - p_acc: 0.9125 - val_p_loss: 0.2163 - val_p_acc: 0.9050
# Epoch 60/100
# 25/25 [==============================] - 654s 26s/step - c_loss: 0.4628 - c_acc: 0.8906 - p_loss: 0.2742 - p_acc: 0.9150 - val_p_loss: 0.3200 - val_p_acc: 0.8600
# Epoch 61/100
# 25/25 [==============================] - 601s 24s/step - c_loss: 0.4720 - c_acc: 0.8841 - p_loss: 0.5213 - p_acc: 0.8625 - val_p_loss: 0.5387 - val_p_acc: 0.8550
# Epoch 62/100
# 25/25 [==============================] - 601s 24s/step - c_loss: 0.4949 - c_acc: 0.8838 - p_loss: 0.4730 - p_acc: 0.8587 - val_p_loss: 0.7629 - val_p_acc: 0.8500
# Epoch 63/100
# 25/25 [==============================] - 614s 24s/step - c_loss: 0.5131 - c_acc: 0.8784 - p_loss: 0.4744 - p_acc: 0.8612 - val_p_loss: 0.4775 - val_p_acc: 0.8800
# Epoch 64/100
# 25/25 [==============================] - 674s 27s/step - c_loss: 0.5273 - c_acc: 0.8631 - p_loss: 0.3866 - p_acc: 0.8938 - val_p_loss: 0.5969 - val_p_acc: 0.8500
# Epoch 65/100
# 25/25 [==============================] - 617s 25s/step - c_loss: 0.5014 - c_acc: 0.8672 - p_loss: 0.3075 - p_acc: 0.9025 - val_p_loss: 0.3373 - val_p_acc: 0.9050
# Epoch 66/100
# 25/25 [==============================] - 616s 24s/step - c_loss: 0.4724 - c_acc: 0.8847 - p_loss: 0.3177 - p_acc: 0.9075 - val_p_loss: 0.2703 - val_p_acc: 0.9200
# Epoch 67/100
# 25/25 [==============================] - 643s 26s/step - c_loss: 0.4612 - c_acc: 0.8913 - p_loss: 0.3795 - p_acc: 0.8825 - val_p_loss: 0.3612 - val_p_acc: 0.8700
# Epoch 68/100
# 25/25 [==============================] - 638s 25s/step - c_loss: 0.4364 - c_acc: 0.8947 - p_loss: 0.3575 - p_acc: 0.8875 - val_p_loss: 0.3970 - val_p_acc: 0.8500
# Epoch 69/100
# 25/25 [==============================] - 622s 25s/step - c_loss: 0.4752 - c_acc: 0.8775 - p_loss: 0.4666 - p_acc: 0.8487 - val_p_loss: 0.7199 - val_p_acc: 0.7800
# Epoch 70/100
# 25/25 [==============================] - 610s 24s/step - c_loss: 0.4820 - c_acc: 0.8794 - p_loss: 0.3239 - p_acc: 0.8988 - val_p_loss: 0.3822 - val_p_acc: 0.9150
# Epoch 71/100
# 25/25 [==============================] - 651s 26s/step - c_loss: 0.4483 - c_acc: 0.8931 - p_loss: 0.4456 - p_acc: 0.8813 - val_p_loss: 0.5426 - val_p_acc: 0.8850
# Epoch 72/100
# 25/25 [==============================] - 684s 27s/step - c_loss: 0.4175 - c_acc: 0.9003 - p_loss: 0.4222 - p_acc: 0.8913 - val_p_loss: 0.4963 - val_p_acc: 0.8900
# Epoch 73/100
# 25/25 [==============================] - 583s 23s/step - c_loss: 0.4110 - c_acc: 0.8978 - p_loss: 0.4896 - p_acc: 0.8900 - val_p_loss: 0.4536 - val_p_acc: 0.8800
# Epoch 74/100
# 25/25 [==============================] - 566s 23s/step - c_loss: 0.3814 - c_acc: 0.9128 - p_loss: 0.3477 - p_acc: 0.8975 - val_p_loss: 0.4437 - val_p_acc: 0.8650
# Epoch 75/100
# 25/25 [==============================] - 586s 23s/step - c_loss: 0.3919 - c_acc: 0.9019 - p_loss: 0.4925 - p_acc: 0.8938 - val_p_loss: 0.3123 - val_p_acc: 0.8900
# Epoch 76/100
# 25/25 [==============================] - 585s 23s/step - c_loss: 0.4167 - c_acc: 0.8978 - p_loss: 0.4793 - p_acc: 0.8813 - val_p_loss: 0.9903 - val_p_acc: 0.7850
# Epoch 77/100
# 25/25 [==============================] - 566s 23s/step - c_loss: 0.4408 - c_acc: 0.8916 - p_loss: 0.4487 - p_acc: 0.8687 - val_p_loss: 0.2132 - val_p_acc: 0.9350
# Epoch 78/100
# 25/25 [==============================] - 566s 23s/step - c_loss: 0.3978 - c_acc: 0.9053 - p_loss: 0.4725 - p_acc: 0.8763 - val_p_loss: 0.8611 - val_p_acc: 0.8300
# Epoch 79/100
# 25/25 [==============================] - 578s 23s/step - c_loss: 0.4072 - c_acc: 0.9084 - p_loss: 0.6023 - p_acc: 0.8413 - val_p_loss: 0.2328 - val_p_acc: 0.9300
# Epoch 80/100
# 25/25 [==============================] - 596s 24s/step - c_loss: 0.4240 - c_acc: 0.8963 - p_loss: 0.3631 - p_acc: 0.8988 - val_p_loss: 0.2767 - val_p_acc: 0.8950
# Epoch 81/100
# 25/25 [==============================] - 560s 22s/step - c_loss: 0.4214 - c_acc: 0.8988 - p_loss: 0.4660 - p_acc: 0.8662 - val_p_loss: 0.5041 - val_p_acc: 0.8500
# Epoch 82/100
# 25/25 [==============================] - 567s 23s/step - c_loss: 0.3882 - c_acc: 0.9044 - p_loss: 0.3352 - p_acc: 0.9062 - val_p_loss: 0.4180 - val_p_acc: 0.8500
# Epoch 83/100
# 25/25 [==============================] - 561s 22s/step - c_loss: 0.3741 - c_acc: 0.9178 - p_loss: 0.3629 - p_acc: 0.8975 - val_p_loss: 0.3909 - val_p_acc: 0.9200
# Epoch 84/100
# 25/25 [==============================] - 686s 28s/step - c_loss: 0.4026 - c_acc: 0.9016 - p_loss: 0.3686 - p_acc: 0.9075 - val_p_loss: 0.5312 - val_p_acc: 0.8500
# Epoch 85/100
# 25/25 [==============================] - 637s 26s/step - c_loss: 0.3771 - c_acc: 0.9062 - p_loss: 0.3231 - p_acc: 0.9062 - val_p_loss: 0.3935 - val_p_acc: 0.9000
# Epoch 86/100
# 25/25 [==============================] - 644s 26s/step - c_loss: 0.3597 - c_acc: 0.9206 - p_loss: 0.4443 - p_acc: 0.8725 - val_p_loss: 0.4915 - val_p_acc: 0.8850
# Epoch 87/100
# 25/25 [==============================] - 635s 25s/step - c_loss: 0.3968 - c_acc: 0.9056 - p_loss: 0.5687 - p_acc: 0.8687 - val_p_loss: 0.5131 - val_p_acc: 0.8500
# Epoch 88/100
# 25/25 [==============================] - 683s 27s/step - c_loss: 0.3548 - c_acc: 0.9175 - p_loss: 0.5702 - p_acc: 0.8687 - val_p_loss: 0.5975 - val_p_acc: 0.8950
# Epoch 89/100
# 25/25 [==============================] - 632s 25s/step - c_loss: 0.3569 - c_acc: 0.9187 - p_loss: 0.5404 - p_acc: 0.8763 - val_p_loss: 0.6273 - val_p_acc: 0.8350
# Epoch 90/100
# 25/25 [==============================] - 640s 26s/step - c_loss: 0.3476 - c_acc: 0.9156 - p_loss: 0.5942 - p_acc: 0.8662 - val_p_loss: 1.5493 - val_p_acc: 0.7350
# Epoch 91/100
# 25/25 [==============================] - 669s 27s/step - c_loss: 0.3256 - c_acc: 0.9259 - p_loss: 0.5100 - p_acc: 0.8925 - val_p_loss: 0.8443 - val_p_acc: 0.8350
# Epoch 92/100
# 25/25 [==============================] - 663s 26s/step - c_loss: 0.3425 - c_acc: 0.9244 - p_loss: 0.4611 - p_acc: 0.8938 - val_p_loss: 0.5963 - val_p_acc: 0.8650
# Epoch 93/100
# 25/25 [==============================] - 641s 26s/step - c_loss: 0.3667 - c_acc: 0.9197 - p_loss: 0.3539 - p_acc: 0.9062 - val_p_loss: 0.3188 - val_p_acc: 0.9050
# Epoch 94/100
# 25/25 [==============================] - 641s 26s/step - c_loss: 0.3603 - c_acc: 0.9094 - p_loss: 0.3253 - p_acc: 0.9087 - val_p_loss: 0.2625 - val_p_acc: 0.9150
# Epoch 95/100
# 25/25 [==============================] - 683s 27s/step - c_loss: 0.3780 - c_acc: 0.9078 - p_loss: 0.3245 - p_acc: 0.9100 - val_p_loss: 0.2124 - val_p_acc: 0.9150
# Epoch 96/100
# 25/25 [==============================] - 664s 27s/step - c_loss: 0.3278 - c_acc: 0.9253 - p_loss: 0.2960 - p_acc: 0.9125 - val_p_loss: 0.8650 - val_p_acc: 0.8150
# Epoch 97/100
# 25/25 [==============================] - 654s 26s/step - c_loss: 0.3480 - c_acc: 0.9162 - p_loss: 0.5735 - p_acc: 0.8813 - val_p_loss: 0.2646 - val_p_acc: 0.9350
# Epoch 98/100
# 25/25 [==============================] - 653s 26s/step - c_loss: 0.3574 - c_acc: 0.9128 - p_loss: 0.2937 - p_acc: 0.9225 - val_p_loss: 0.3230 - val_p_acc: 0.8800
# Epoch 99/100
# 25/25 [==============================] - 692s 28s/step - c_loss: 0.3527 - c_acc: 0.9178 - p_loss: 0.3116 - p_acc: 0.9112 - val_p_loss: 0.4038 - val_p_acc: 0.8700
# Epoch 100/100
# 25/25 [==============================] - 648s 26s/step - c_loss: 0.3503 - c_acc: 0.9219 - p_loss: 0.3396 - p_acc: 0.9050 - val_p_loss: 0.2637 - val_p_acc: 0.9100
# Maximal validation accuracy: 93.50%

# %% [markdown]
# ## Supervised finetuning of the pretrained encoder - Student Net

# %%
# Supervised finetuning of the pretrained encoder - Student Net
finetuning_model = keras.Sequential(
    [
        layers.Input(shape=(image_size, image_size, image_channels)),
        get_augmenter(**classification_augmentation),
        pretraining_model.encoder,
        layers.Dense(4),
    ],
    name="finetuning_model",
)
#In the above model initiation, we call the pretraining_model.encoder, sharing the trained resnet with the student net

finetuning_model.compile(
    optimizer=keras.optimizers.Adam(),
    loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=[keras.metrics.SparseCategoricalAccuracy(name="acc"),
             keras.metrics.TopKCategoricalAccuracy(k = 1, name="top1_acc"),
             keras.metrics.TopKCategoricalAccuracy(k = 2, name="top2_acc"),
             keras.metrics.TopKCategoricalAccuracy(k = 3, name="top3_acc"), 
            ],
)

finetuning_history = finetuning_model.fit(
    labeled_train_dataset, epochs=num_epochs, validation_data=test_dataset
)
print(
    "Maximal validation accuracy: {:.2f}%".format(
        max(finetuning_history.history["val_acc"]) * 100
    )
)
# Out:
# Epoch 1/100
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3
# 25/25 [==============================] - 167s 6s/step - loss: 1.3659 - acc: 0.7750 - top1_acc: 0.2512 - top2_acc: 0.4013 - top3_acc: 0.5525 - val_loss: 1.9245 - val_acc: 0.6700 - val_top1_acc: 0.0600 - val_top2_acc: 0.1250 - val_top3_acc: 0.2000
# Epoch 2/100
# 25/25 [==============================] - 161s 6s/step - loss: 0.1810 - acc: 0.9513 - top1_acc: 0.2587 - top2_acc: 0.4837 - top3_acc: 0.7225 - val_loss: 0.3873 - val_acc: 0.9050 - val_top1_acc: 0.1750 - val_top2_acc: 0.2550 - val_top3_acc: 0.3750
# Epoch 3/100
# 25/25 [==============================] - 163s 7s/step - loss: 0.0843 - acc: 0.9750 - top1_acc: 0.2488 - top2_acc: 0.4313 - top3_acc: 0.6800 - val_loss: 0.4797 - val_acc: 0.9050 - val_top1_acc: 0.1700 - val_top2_acc: 0.3150 - val_top3_acc: 0.4550
# Epoch 4/100
# 25/25 [==============================] - 163s 7s/step - loss: 0.0722 - acc: 0.9825 - top1_acc: 0.2500 - top2_acc: 0.4625 - top3_acc: 0.7188 - val_loss: 0.0808 - val_acc: 0.9650 - val_top1_acc: 0.2600 - val_top2_acc: 0.5300 - val_top3_acc: 0.7950
# Epoch 5/100
# 25/25 [==============================] - 162s 7s/step - loss: 0.0373 - acc: 0.9875 - top1_acc: 0.2512 - top2_acc: 0.5537 - top3_acc: 0.7800 - val_loss: 0.0847 - val_acc: 0.9750 - val_top1_acc: 0.2300 - val_top2_acc: 0.3300 - val_top3_acc: 0.7950
# Epoch 6/100
# 25/25 [==============================] - 162s 6s/step - loss: 0.0243 - acc: 0.9887 - top1_acc: 0.2525 - top2_acc: 0.4963 - top3_acc: 0.6587 - val_loss: 0.1486 - val_acc: 0.9700 - val_top1_acc: 0.2300 - val_top2_acc: 0.2950 - val_top3_acc: 0.4700
# Epoch 7/100
# 25/25 [==============================] - 161s 6s/step - loss: 0.0351 - acc: 0.9875 - top1_acc: 0.2525 - top2_acc: 0.4888 - top3_acc: 0.6200 - val_loss: 0.1930 - val_acc: 0.9650 - val_top1_acc: 0.2200 - val_top2_acc: 0.3300 - val_top3_acc: 0.5450
# Epoch 8/100
# 25/25 [==============================] - 167s 7s/step - loss: 0.0741 - acc: 0.9850 - top1_acc: 0.2525 - top2_acc: 0.4950 - top3_acc: 0.6662 - val_loss: 0.3133 - val_acc: 0.9250 - val_top1_acc: 0.3050 - val_top2_acc: 0.7650 - val_top3_acc: 0.9400
# Epoch 9/100
# 25/25 [==============================] - 168s 7s/step - loss: 0.0646 - acc: 0.9825 - top1_acc: 0.2500 - top2_acc: 0.5537 - top3_acc: 0.7563 - val_loss: 1.0713 - val_acc: 0.7550 - val_top1_acc: 0.2950 - val_top2_acc: 0.6300 - val_top3_acc: 0.8200
# Epoch 10/100
# 25/25 [==============================] - 170s 7s/step - loss: 0.1085 - acc: 0.9762 - top1_acc: 0.2537 - top2_acc: 0.4137 - top3_acc: 0.7400 - val_loss: 0.7088 - val_acc: 0.8850 - val_top1_acc: 0.2650 - val_top2_acc: 0.4150 - val_top3_acc: 0.8450
# Epoch 11/100
# 25/25 [==============================] - 166s 7s/step - loss: 0.1183 - acc: 0.9775 - top1_acc: 0.2488 - top2_acc: 0.4400 - top3_acc: 0.7088 - val_loss: 2.1852 - val_acc: 0.6900 - val_top1_acc: 0.2100 - val_top2_acc: 0.3000 - val_top3_acc: 0.5800
# Epoch 12/100
# 25/25 [==============================] - 162s 6s/step - loss: 0.0740 - acc: 0.9862 - top1_acc: 0.2562 - top2_acc: 0.6225 - top3_acc: 0.7312 - val_loss: 2.7024 - val_acc: 0.6000 - val_top1_acc: 0.3100 - val_top2_acc: 0.7400 - val_top3_acc: 0.9800
# Epoch 13/100
# 25/25 [==============================] - 163s 7s/step - loss: 0.0310 - acc: 0.9875 - top1_acc: 0.2512 - top2_acc: 0.6600 - top3_acc: 0.7750 - val_loss: 2.1421 - val_acc: 0.6950 - val_top1_acc: 0.2250 - val_top2_acc: 0.5600 - val_top3_acc: 0.8450
# Epoch 14/100
# 25/25 [==============================] - 162s 7s/step - loss: 0.0268 - acc: 0.9900 - top1_acc: 0.2512 - top2_acc: 0.7412 - top3_acc: 0.7962 - val_loss: 0.0631 - val_acc: 0.9850 - val_top1_acc: 0.2500 - val_top2_acc: 0.6400 - val_top3_acc: 0.7300
# Epoch 15/100
# 25/25 [==============================] - 165s 7s/step - loss: 0.0109 - acc: 0.9975 - top1_acc: 0.2512 - top2_acc: 0.5462 - top3_acc: 0.6500 - val_loss: 0.0742 - val_acc: 0.9750 - val_top1_acc: 0.2450 - val_top2_acc: 0.4500 - val_top3_acc: 0.6250
# Epoch 16/100
# 25/25 [==============================] - 162s 6s/step - loss: 0.0049 - acc: 0.9987 - top1_acc: 0.2525 - top2_acc: 0.4462 - top3_acc: 0.6388 - val_loss: 0.0034 - val_acc: 1.0000 - val_top1_acc: 0.2400 - val_top2_acc: 0.2850 - val_top3_acc: 0.5300
# Epoch 17/100
# 25/25 [==============================] - 163s 7s/step - loss: 0.0321 - acc: 0.9900 - top1_acc: 0.2512 - top2_acc: 0.4963 - top3_acc: 0.6175 - val_loss: 0.3298 - val_acc: 0.9750 - val_top1_acc: 0.2150 - val_top2_acc: 0.3400 - val_top3_acc: 0.4650
# Epoch 18/100
# 25/25 [==============================] - 162s 6s/step - loss: 0.0241 - acc: 0.9900 - top1_acc: 0.2537 - top2_acc: 0.5275 - top3_acc: 0.6425 - val_loss: 5.1618 - val_acc: 0.5300 - val_top1_acc: 0.0650 - val_top2_acc: 0.1750 - val_top3_acc: 0.3450
# Epoch 19/100
# 25/25 [==============================] - 163s 7s/step - loss: 0.0262 - acc: 0.9925 - top1_acc: 0.2500 - top2_acc: 0.6050 - top3_acc: 0.7663 - val_loss: 0.2590 - val_acc: 0.9600 - val_top1_acc: 0.2150 - val_top2_acc: 0.4800 - val_top3_acc: 0.7150
# Epoch 20/100
# 25/25 [==============================] - 163s 7s/step - loss: 0.0281 - acc: 0.9912 - top1_acc: 0.2537 - top2_acc: 0.6463 - top3_acc: 0.7362 - val_loss: 0.2009 - val_acc: 0.9550 - val_top1_acc: 0.2650 - val_top2_acc: 0.6800 - val_top3_acc: 0.8100
# Epoch 21/100
# 25/25 [==============================] - 162s 6s/step - loss: 0.0485 - acc: 0.9937 - top1_acc: 0.2512 - top2_acc: 0.5138 - top3_acc: 0.6700 - val_loss: 0.1007 - val_acc: 0.9800 - val_top1_acc: 0.2550 - val_top2_acc: 0.4650 - val_top3_acc: 0.5900
# Epoch 22/100
# 25/25 [==============================] - 165s 7s/step - loss: 0.0161 - acc: 0.9950 - top1_acc: 0.2550 - top2_acc: 0.5312 - top3_acc: 0.6700 - val_loss: 0.0738 - val_acc: 0.9900 - val_top1_acc: 0.2400 - val_top2_acc: 0.3100 - val_top3_acc: 0.5250
# Epoch 23/100
# 25/25 [==============================] - 166s 7s/step - loss: 0.0257 - acc: 0.9912 - top1_acc: 0.2537 - top2_acc: 0.5362 - top3_acc: 0.6837 - val_loss: 0.0212 - val_acc: 0.9900 - val_top1_acc: 0.2450 - val_top2_acc: 0.5500 - val_top3_acc: 0.7100
# Epoch 24/100
# 25/25 [==============================] - 171s 7s/step - loss: 0.0237 - acc: 0.9912 - top1_acc: 0.2525 - top2_acc: 0.5025 - top3_acc: 0.7063 - val_loss: 0.8345 - val_acc: 0.8500 - val_top1_acc: 0.2750 - val_top2_acc: 0.7000 - val_top3_acc: 0.7850
# Epoch 25/100
# 25/25 [==============================] - 169s 7s/step - loss: 0.0178 - acc: 0.9937 - top1_acc: 0.2537 - top2_acc: 0.5913 - top3_acc: 0.6612 - val_loss: 0.5263 - val_acc: 0.9300 - val_top1_acc: 0.2850 - val_top2_acc: 0.5700 - val_top3_acc: 0.7150
# Epoch 26/100
# 25/25 [==============================] - 164s 7s/step - loss: 0.0443 - acc: 0.9875 - top1_acc: 0.2562 - top2_acc: 0.5238 - top3_acc: 0.6150 - val_loss: 0.2769 - val_acc: 0.9450 - val_top1_acc: 0.2150 - val_top2_acc: 0.3100 - val_top3_acc: 0.7650
# Epoch 27/100
# 25/25 [==============================] - 163s 7s/step - loss: 0.0919 - acc: 0.9812 - top1_acc: 0.2475 - top2_acc: 0.5075 - top3_acc: 0.6488 - val_loss: 0.7707 - val_acc: 0.8350 - val_top1_acc: 0.2050 - val_top2_acc: 0.4050 - val_top3_acc: 0.5500
# Epoch 28/100
# 25/25 [==============================] - 164s 7s/step - loss: 0.0608 - acc: 0.9862 - top1_acc: 0.2488 - top2_acc: 0.6313 - top3_acc: 0.8213 - val_loss: 1.7239 - val_acc: 0.5500 - val_top1_acc: 0.5000 - val_top2_acc: 0.9850 - val_top3_acc: 1.0000
# Epoch 29/100
# 25/25 [==============================] - 163s 7s/step - loss: 0.0877 - acc: 0.9725 - top1_acc: 0.2550 - top2_acc: 0.6313 - top3_acc: 0.9312 - val_loss: 2.4352 - val_acc: 0.6450 - val_top1_acc: 0.0650 - val_top2_acc: 0.2900 - val_top3_acc: 0.8050
# Epoch 30/100
# 25/25 [==============================] - 164s 7s/step - loss: 0.0601 - acc: 0.9787 - top1_acc: 0.2550 - top2_acc: 0.7300 - top3_acc: 0.9362 - val_loss: 2.0611 - val_acc: 0.7650 - val_top1_acc: 0.1200 - val_top2_acc: 0.2500 - val_top3_acc: 0.7950
# Epoch 31/100
# 25/25 [==============================] - 163s 7s/step - loss: 0.0643 - acc: 0.9825 - top1_acc: 0.2537 - top2_acc: 0.6375 - top3_acc: 0.8200 - val_loss: 1.1550 - val_acc: 0.8600 - val_top1_acc: 0.1900 - val_top2_acc: 0.6350 - val_top3_acc: 0.9300
# Epoch 32/100
# 25/25 [==============================] - 164s 7s/step - loss: 0.0945 - acc: 0.9775 - top1_acc: 0.2550 - top2_acc: 0.5725 - top3_acc: 0.8100 - val_loss: 2.2253 - val_acc: 0.7800 - val_top1_acc: 0.0800 - val_top2_acc: 0.2300 - val_top3_acc: 0.5850
# Epoch 33/100
# 25/25 [==============================] - 164s 7s/step - loss: 0.0425 - acc: 0.9900 - top1_acc: 0.2463 - top2_acc: 0.5875 - top3_acc: 0.7462 - val_loss: 0.1082 - val_acc: 0.9800 - val_top1_acc: 0.2450 - val_top2_acc: 0.7200 - val_top3_acc: 0.9150
# Epoch 34/100
# 25/25 [==============================] - 163s 7s/step - loss: 0.0282 - acc: 0.9937 - top1_acc: 0.2537 - top2_acc: 0.7275 - top3_acc: 0.8225 - val_loss: 0.0837 - val_acc: 0.9800 - val_top1_acc: 0.2400 - val_top2_acc: 0.6650 - val_top3_acc: 0.7200
# Epoch 35/100
# 25/25 [==============================] - 164s 7s/step - loss: 0.0118 - acc: 0.9962 - top1_acc: 0.2512 - top2_acc: 0.6862 - top3_acc: 0.7563 - val_loss: 0.0890 - val_acc: 0.9800 - val_top1_acc: 0.2450 - val_top2_acc: 0.7050 - val_top3_acc: 0.7350
# Epoch 36/100
# 25/25 [==============================] - 164s 7s/step - loss: 0.0068 - acc: 0.9987 - top1_acc: 0.2537 - top2_acc: 0.7237 - top3_acc: 0.7563 - val_loss: 0.0725 - val_acc: 0.9850 - val_top1_acc: 0.2350 - val_top2_acc: 0.6650 - val_top3_acc: 0.7200
# Epoch 37/100
# 25/25 [==============================] - 167s 7s/step - loss: 0.0029 - acc: 1.0000 - top1_acc: 0.2525 - top2_acc: 0.7163 - top3_acc: 0.7538 - val_loss: 0.0425 - val_acc: 0.9950 - val_top1_acc: 0.2400 - val_top2_acc: 0.6950 - val_top3_acc: 0.7250
# Epoch 38/100
# 25/25 [==============================] - 170s 7s/step - loss: 0.0096 - acc: 0.9975 - top1_acc: 0.2500 - top2_acc: 0.7013 - top3_acc: 0.7462 - val_loss: 0.0465 - val_acc: 0.9900 - val_top1_acc: 0.2450 - val_top2_acc: 0.7100 - val_top3_acc: 0.7250
# Epoch 39/100
# 25/25 [==============================] - 171s 7s/step - loss: 6.3501e-04 - acc: 1.0000 - top1_acc: 0.2525 - top2_acc: 0.7163 - top3_acc: 0.7600 - val_loss: 0.0547 - val_acc: 0.9900 - val_top1_acc: 0.2450 - val_top2_acc: 0.7050 - val_top3_acc: 0.7250
# Epoch 40/100
# 25/25 [==============================] - 164s 7s/step - loss: 0.0061 - acc: 0.9962 - top1_acc: 0.2537 - top2_acc: 0.7100 - top3_acc: 0.7513 - val_loss: 0.0528 - val_acc: 0.9850 - val_top1_acc: 0.2500 - val_top2_acc: 0.7000 - val_top3_acc: 0.7250
# Epoch 41/100
# 25/25 [==============================] - 164s 7s/step - loss: 0.0049 - acc: 0.9987 - top1_acc: 0.2525 - top2_acc: 0.7063 - top3_acc: 0.7475 - val_loss: 0.0699 - val_acc: 0.9750 - val_top1_acc: 0.2400 - val_top2_acc: 0.7250 - val_top3_acc: 0.7600
# Epoch 42/100
# 25/25 [==============================] - 163s 7s/step - loss: 0.0346 - acc: 0.9925 - top1_acc: 0.2525 - top2_acc: 0.6100 - top3_acc: 0.7688 - val_loss: 0.1357 - val_acc: 0.9700 - val_top1_acc: 0.2500 - val_top2_acc: 0.5600 - val_top3_acc: 0.9350
# Epoch 43/100
# 25/25 [==============================] - 163s 7s/step - loss: 0.0153 - acc: 0.9975 - top1_acc: 0.2550 - top2_acc: 0.6513 - top3_acc: 0.7550 - val_loss: 0.1312 - val_acc: 0.9700 - val_top1_acc: 0.2500 - val_top2_acc: 0.7050 - val_top3_acc: 0.7400
# Epoch 44/100
# 25/25 [==============================] - 164s 7s/step - loss: 0.0174 - acc: 0.9962 - top1_acc: 0.2525 - top2_acc: 0.6100 - top3_acc: 0.7462 - val_loss: 0.1295 - val_acc: 0.9600 - val_top1_acc: 0.2500 - val_top2_acc: 0.5900 - val_top3_acc: 0.7550
# Epoch 45/100
# 25/25 [==============================] - 163s 7s/step - loss: 0.0027 - acc: 0.9987 - top1_acc: 0.2525 - top2_acc: 0.5288 - top3_acc: 0.7362 - val_loss: 0.1471 - val_acc: 0.9600 - val_top1_acc: 0.2450 - val_top2_acc: 0.5750 - val_top3_acc: 0.7400
# Epoch 46/100
# 25/25 [==============================] - 164s 7s/step - loss: 0.0042 - acc: 0.9987 - top1_acc: 0.2512 - top2_acc: 0.6087 - top3_acc: 0.7462 - val_loss: 0.0488 - val_acc: 0.9850 - val_top1_acc: 0.2450 - val_top2_acc: 0.6550 - val_top3_acc: 0.7350
# Epoch 47/100
# 25/25 [==============================] - 163s 7s/step - loss: 0.0038 - acc: 0.9987 - top1_acc: 0.2537 - top2_acc: 0.5750 - top3_acc: 0.7138 - val_loss: 0.0918 - val_acc: 0.9900 - val_top1_acc: 0.2300 - val_top2_acc: 0.4850 - val_top3_acc: 0.5800
# Epoch 48/100
# 25/25 [==============================] - 168s 7s/step - loss: 0.0050 - acc: 0.9975 - top1_acc: 0.2500 - top2_acc: 0.5138 - top3_acc: 0.6950 - val_loss: 0.1320 - val_acc: 0.9650 - val_top1_acc: 0.2300 - val_top2_acc: 0.5150 - val_top3_acc: 0.7000
# Epoch 49/100
# 25/25 [==============================] - 165s 7s/step - loss: 0.0106 - acc: 0.9975 - top1_acc: 0.2525 - top2_acc: 0.5675 - top3_acc: 0.6913 - val_loss: 0.8208 - val_acc: 0.8200 - val_top1_acc: 0.4100 - val_top2_acc: 0.9300 - val_top3_acc: 0.9950
# Epoch 50/100
# 25/25 [==============================] - 165s 7s/step - loss: 0.0070 - acc: 0.9975 - top1_acc: 0.2550 - top2_acc: 0.5650 - top3_acc: 0.6787 - val_loss: 0.3189 - val_acc: 0.9000 - val_top1_acc: 0.3150 - val_top2_acc: 0.4750 - val_top3_acc: 0.6650
# Epoch 51/100
# 25/25 [==============================] - 167s 7s/step - loss: 0.0887 - acc: 0.9787 - top1_acc: 0.2562 - top2_acc: 0.4512 - top3_acc: 0.6212 - val_loss: 0.9454 - val_acc: 0.6950 - val_top1_acc: 0.4700 - val_top2_acc: 0.7300 - val_top3_acc: 0.8900
# Epoch 52/100
# 25/25 [==============================] - 170s 7s/step - loss: 0.0984 - acc: 0.9762 - top1_acc: 0.2537 - top2_acc: 0.4263 - top3_acc: 0.5425 - val_loss: 0.3955 - val_acc: 0.9000 - val_top1_acc: 0.2100 - val_top2_acc: 0.5100 - val_top3_acc: 0.7350
# Epoch 53/100
# 25/25 [==============================] - 172s 7s/step - loss: 0.1074 - acc: 0.9762 - top1_acc: 0.2600 - top2_acc: 0.7113 - top3_acc: 0.7850 - val_loss: 3.2697 - val_acc: 0.7750 - val_top1_acc: 0.1500 - val_top2_acc: 0.3150 - val_top3_acc: 0.7350
# Epoch 54/100
# 25/25 [==============================] - 167s 7s/step - loss: 0.0966 - acc: 0.9762 - top1_acc: 0.2537 - top2_acc: 0.7138 - top3_acc: 0.8250 - val_loss: 0.2854 - val_acc: 0.9050 - val_top1_acc: 0.3250 - val_top2_acc: 0.8400 - val_top3_acc: 1.0000
# Epoch 55/100
# 25/25 [==============================] - 165s 7s/step - loss: 0.0392 - acc: 0.9875 - top1_acc: 0.2562 - top2_acc: 0.6825 - top3_acc: 0.8775 - val_loss: 0.6812 - val_acc: 0.8250 - val_top1_acc: 0.3350 - val_top2_acc: 0.5700 - val_top3_acc: 0.7400
# Epoch 56/100
# 25/25 [==============================] - 164s 7s/step - loss: 0.0342 - acc: 0.9912 - top1_acc: 0.2512 - top2_acc: 0.4462 - top3_acc: 0.7000 - val_loss: 0.4051 - val_acc: 0.8900 - val_top1_acc: 0.3050 - val_top2_acc: 0.5050 - val_top3_acc: 0.7100
# Epoch 57/100
# 25/25 [==============================] - 165s 7s/step - loss: 0.0806 - acc: 0.9825 - top1_acc: 0.2512 - top2_acc: 0.4013 - top3_acc: 0.6225 - val_loss: 0.0203 - val_acc: 0.9950 - val_top1_acc: 0.2350 - val_top2_acc: 0.5050 - val_top3_acc: 0.5700
# Epoch 58/100
# 25/25 [==============================] - 164s 7s/step - loss: 0.0314 - acc: 0.9900 - top1_acc: 0.2612 - top2_acc: 0.3762 - top3_acc: 0.4550 - val_loss: 0.1803 - val_acc: 0.9550 - val_top1_acc: 0.2150 - val_top2_acc: 0.2350 - val_top3_acc: 0.3000
# Epoch 59/100
# 25/25 [==============================] - 166s 7s/step - loss: 0.0731 - acc: 0.9825 - top1_acc: 0.2537 - top2_acc: 0.3900 - top3_acc: 0.5250 - val_loss: 0.0621 - val_acc: 0.9900 - val_top1_acc: 0.2350 - val_top2_acc: 0.4200 - val_top3_acc: 0.6450
# Epoch 60/100
# 25/25 [==============================] - 164s 7s/step - loss: 0.0460 - acc: 0.9837 - top1_acc: 0.2512 - top2_acc: 0.6012 - top3_acc: 0.7337 - val_loss: 1.1036 - val_acc: 0.8150 - val_top1_acc: 0.2650 - val_top2_acc: 0.4900 - val_top3_acc: 0.5600
# Epoch 61/100
# 25/25 [==============================] - 164s 7s/step - loss: 0.0172 - acc: 0.9950 - top1_acc: 0.2525 - top2_acc: 0.6963 - top3_acc: 0.7575 - val_loss: 1.0371 - val_acc: 0.8450 - val_top1_acc: 0.2300 - val_top2_acc: 0.4700 - val_top3_acc: 0.5700
# Epoch 62/100
# 25/25 [==============================] - 164s 7s/step - loss: 0.0094 - acc: 0.9962 - top1_acc: 0.2512 - top2_acc: 0.7113 - top3_acc: 0.7525 - val_loss: 0.0630 - val_acc: 0.9850 - val_top1_acc: 0.2400 - val_top2_acc: 0.6300 - val_top3_acc: 0.7150
# Epoch 63/100
# 25/25 [==============================] - 164s 7s/step - loss: 0.0027 - acc: 1.0000 - top1_acc: 0.2525 - top2_acc: 0.6938 - top3_acc: 0.7525 - val_loss: 0.0952 - val_acc: 0.9750 - val_top1_acc: 0.2550 - val_top2_acc: 0.6750 - val_top3_acc: 0.7150
# Epoch 64/100
# 25/25 [==============================] - 165s 7s/step - loss: 0.0131 - acc: 0.9975 - top1_acc: 0.2525 - top2_acc: 0.7275 - top3_acc: 0.7550 - val_loss: 0.1084 - val_acc: 0.9750 - val_top1_acc: 0.2550 - val_top2_acc: 0.6800 - val_top3_acc: 0.7200
# Epoch 65/100
# 25/25 [==============================] - 167s 7s/step - loss: 0.0043 - acc: 0.9987 - top1_acc: 0.2537 - top2_acc: 0.7200 - top3_acc: 0.7563 - val_loss: 0.0212 - val_acc: 0.9900 - val_top1_acc: 0.2500 - val_top2_acc: 0.5700 - val_top3_acc: 0.7200
# Epoch 66/100
# 25/25 [==============================] - 170s 7s/step - loss: 0.0292 - acc: 0.9925 - top1_acc: 0.2488 - top2_acc: 0.6812 - top3_acc: 0.7513 - val_loss: 0.0517 - val_acc: 0.9900 - val_top1_acc: 0.2400 - val_top2_acc: 0.6400 - val_top3_acc: 0.7200
# Epoch 67/100
# 25/25 [==============================] - 172s 7s/step - loss: 0.0047 - acc: 0.9975 - top1_acc: 0.2537 - top2_acc: 0.7212 - top3_acc: 0.7625 - val_loss: 0.0580 - val_acc: 0.9900 - val_top1_acc: 0.2300 - val_top2_acc: 0.5800 - val_top3_acc: 0.7300
# Epoch 68/100
# 25/25 [==============================] - 169s 7s/step - loss: 0.0075 - acc: 0.9987 - top1_acc: 0.2512 - top2_acc: 0.7375 - top3_acc: 0.7563 - val_loss: 0.0177 - val_acc: 0.9950 - val_top1_acc: 0.2450 - val_top2_acc: 0.7250 - val_top3_acc: 0.7300
# Epoch 69/100
# 25/25 [==============================] - 165s 7s/step - loss: 0.0055 - acc: 0.9975 - top1_acc: 0.2525 - top2_acc: 0.7400 - top3_acc: 0.7588 - val_loss: 0.0748 - val_acc: 0.9750 - val_top1_acc: 0.2150 - val_top2_acc: 0.7250 - val_top3_acc: 0.7300
# Epoch 70/100
# 25/25 [==============================] - 167s 7s/step - loss: 0.0032 - acc: 0.9987 - top1_acc: 0.2537 - top2_acc: 0.7462 - top3_acc: 0.7575 - val_loss: 0.0145 - val_acc: 0.9950 - val_top1_acc: 0.2350 - val_top2_acc: 0.7250 - val_top3_acc: 0.7300
# Epoch 71/100
# 25/25 [==============================] - 164s 7s/step - loss: 0.0056 - acc: 0.9987 - top1_acc: 0.2537 - top2_acc: 0.7300 - top3_acc: 0.7575 - val_loss: 0.0370 - val_acc: 0.9900 - val_top1_acc: 0.2400 - val_top2_acc: 0.7000 - val_top3_acc: 0.7300
# Epoch 72/100
# 25/25 [==============================] - 165s 7s/step - loss: 8.4300e-04 - acc: 1.0000 - top1_acc: 0.2525 - top2_acc: 0.7237 - top3_acc: 0.7575 - val_loss: 0.0158 - val_acc: 0.9950 - val_top1_acc: 0.2350 - val_top2_acc: 0.7050 - val_top3_acc: 0.7300
# Epoch 73/100
# 25/25 [==============================] - 165s 7s/step - loss: 0.0042 - acc: 0.9962 - top1_acc: 0.2512 - top2_acc: 0.7225 - top3_acc: 0.7563 - val_loss: 0.0125 - val_acc: 0.9950 - val_top1_acc: 0.2350 - val_top2_acc: 0.7200 - val_top3_acc: 0.7300
# Epoch 74/100
# 25/25 [==============================] - 164s 7s/step - loss: 0.0019 - acc: 0.9987 - top1_acc: 0.2525 - top2_acc: 0.7350 - top3_acc: 0.7563 - val_loss: 0.0258 - val_acc: 0.9950 - val_top1_acc: 0.2350 - val_top2_acc: 0.6550 - val_top3_acc: 0.7300
# Epoch 75/100
# 25/25 [==============================] - 165s 7s/step - loss: 0.0016 - acc: 1.0000 - top1_acc: 0.2525 - top2_acc: 0.7212 - top3_acc: 0.7575 - val_loss: 0.0021 - val_acc: 1.0000 - val_top1_acc: 0.2400 - val_top2_acc: 0.7050 - val_top3_acc: 0.7300
# Epoch 76/100
# 25/25 [==============================] - 164s 7s/step - loss: 0.0051 - acc: 0.9987 - top1_acc: 0.2537 - top2_acc: 0.7100 - top3_acc: 0.7550 - val_loss: 0.0070 - val_acc: 0.9950 - val_top1_acc: 0.2350 - val_top2_acc: 0.7000 - val_top3_acc: 0.7300
# Epoch 77/100
# 25/25 [==============================] - 166s 7s/step - loss: 0.0018 - acc: 1.0000 - top1_acc: 0.2525 - top2_acc: 0.7200 - top3_acc: 0.7563 - val_loss: 0.0014 - val_acc: 1.0000 - val_top1_acc: 0.2400 - val_top2_acc: 0.7200 - val_top3_acc: 0.7400
# Epoch 78/100
# 25/25 [==============================] - 165s 7s/step - loss: 6.1356e-04 - acc: 1.0000 - top1_acc: 0.2525 - top2_acc: 0.7425 - top3_acc: 0.7638 - val_loss: 0.0010 - val_acc: 1.0000 - val_top1_acc: 0.2400 - val_top2_acc: 0.7150 - val_top3_acc: 0.7400
# Epoch 79/100
# 25/25 [==============================] - 167s 7s/step - loss: 0.0391 - acc: 0.9937 - top1_acc: 0.2525 - top2_acc: 0.6425 - top3_acc: 0.7525 - val_loss: 0.0652 - val_acc: 0.9900 - val_top1_acc: 0.2350 - val_top2_acc: 0.4850 - val_top3_acc: 0.7100
# Epoch 80/100
# 25/25 [==============================] - 168s 7s/step - loss: 0.0073 - acc: 0.9975 - top1_acc: 0.2537 - top2_acc: 0.5088 - top3_acc: 0.7450 - val_loss: 0.1117 - val_acc: 0.9850 - val_top1_acc: 0.2250 - val_top2_acc: 0.3350 - val_top3_acc: 0.6250
# Epoch 81/100
# 25/25 [==============================] - 173s 7s/step - loss: 0.0034 - acc: 0.9975 - top1_acc: 0.2512 - top2_acc: 0.5188 - top3_acc: 0.7113 - val_loss: 0.0064 - val_acc: 0.9950 - val_top1_acc: 0.2350 - val_top2_acc: 0.4350 - val_top3_acc: 0.7150
# Epoch 82/100
# 25/25 [==============================] - 170s 7s/step - loss: 9.9411e-04 - acc: 1.0000 - top1_acc: 0.2525 - top2_acc: 0.6400 - top3_acc: 0.7500 - val_loss: 0.0026 - val_acc: 1.0000 - val_top1_acc: 0.2400 - val_top2_acc: 0.5750 - val_top3_acc: 0.7250
# Epoch 83/100
# 25/25 [==============================] - 164s 7s/step - loss: 0.0054 - acc: 0.9987 - top1_acc: 0.2537 - top2_acc: 0.5875 - top3_acc: 0.7312 - val_loss: 0.0275 - val_acc: 0.9950 - val_top1_acc: 0.2350 - val_top2_acc: 0.5200 - val_top3_acc: 0.7100
# Epoch 84/100
# 25/25 [==============================] - 164s 7s/step - loss: 0.0149 - acc: 0.9937 - top1_acc: 0.2525 - top2_acc: 0.6575 - top3_acc: 0.7425 - val_loss: 0.0270 - val_acc: 0.9950 - val_top1_acc: 0.2400 - val_top2_acc: 0.6350 - val_top3_acc: 0.7200
# Epoch 85/100
# 25/25 [==============================] - 164s 7s/step - loss: 0.0137 - acc: 0.9962 - top1_acc: 0.2525 - top2_acc: 0.5312 - top3_acc: 0.6037 - val_loss: 0.3124 - val_acc: 0.9200 - val_top1_acc: 0.2500 - val_top2_acc: 0.5100 - val_top3_acc: 0.6650
# Epoch 86/100
# 25/25 [==============================] - 166s 7s/step - loss: 0.0207 - acc: 0.9962 - top1_acc: 0.2500 - top2_acc: 0.5250 - top3_acc: 0.6463 - val_loss: 0.2105 - val_acc: 0.9500 - val_top1_acc: 0.2400 - val_top2_acc: 0.6000 - val_top3_acc: 0.7050
# Epoch 87/100
# 25/25 [==============================] - 164s 7s/step - loss: 0.0350 - acc: 0.9825 - top1_acc: 0.2575 - top2_acc: 0.5312 - top3_acc: 0.6175 - val_loss: 0.4225 - val_acc: 0.8350 - val_top1_acc: 0.3850 - val_top2_acc: 0.6750 - val_top3_acc: 0.7300
# Epoch 88/100
# 25/25 [==============================] - 165s 7s/step - loss: 0.0310 - acc: 0.9912 - top1_acc: 0.2537 - top2_acc: 0.4375 - top3_acc: 0.6700 - val_loss: 0.3010 - val_acc: 0.9400 - val_top1_acc: 0.2650 - val_top2_acc: 0.4200 - val_top3_acc: 0.6650
# Epoch 89/100
# 25/25 [==============================] - 166s 7s/step - loss: 0.0193 - acc: 0.9912 - top1_acc: 0.2500 - top2_acc: 0.5950 - top3_acc: 0.7425 - val_loss: 0.2505 - val_acc: 0.9550 - val_top1_acc: 0.2650 - val_top2_acc: 0.6400 - val_top3_acc: 0.7300
# Epoch 90/100
# 25/25 [==============================] - 164s 7s/step - loss: 0.0207 - acc: 0.9950 - top1_acc: 0.2537 - top2_acc: 0.5713 - top3_acc: 0.6750 - val_loss: 0.2388 - val_acc: 0.9400 - val_top1_acc: 0.1900 - val_top2_acc: 0.4450 - val_top3_acc: 0.4700
# Epoch 91/100
# 25/25 [==============================] - 164s 7s/step - loss: 0.0365 - acc: 0.9875 - top1_acc: 0.2550 - top2_acc: 0.5013 - top3_acc: 0.5100 - val_loss: 0.3340 - val_acc: 0.9350 - val_top1_acc: 0.1950 - val_top2_acc: 0.3400 - val_top3_acc: 0.4200
# Epoch 92/100
# 25/25 [==============================] - 166s 7s/step - loss: 0.1899 - acc: 0.9675 - top1_acc: 0.2550 - top2_acc: 0.4050 - top3_acc: 0.4925 - val_loss: 1.5801 - val_acc: 0.8150 - val_top1_acc: 0.1450 - val_top2_acc: 0.2100 - val_top3_acc: 0.2350
# Epoch 93/100
# 25/25 [==============================] - 165s 7s/step - loss: 0.1398 - acc: 0.9625 - top1_acc: 0.2587 - top2_acc: 0.3300 - top3_acc: 0.4762 - val_loss: 10.5925 - val_acc: 0.4750 - val_top1_acc: 0.1300 - val_top2_acc: 0.1900 - val_top3_acc: 0.4300
# Epoch 94/100
# 25/25 [==============================] - 167s 7s/step - loss: 0.0378 - acc: 0.9875 - top1_acc: 0.2512 - top2_acc: 0.4975 - top3_acc: 0.6775 - val_loss: 4.1741 - val_acc: 0.7400 - val_top1_acc: 0.0400 - val_top2_acc: 0.2700 - val_top3_acc: 0.6500
# Epoch 95/100
# 25/25 [==============================] - 171s 7s/step - loss: 0.0415 - acc: 0.9912 - top1_acc: 0.2537 - top2_acc: 0.6687 - top3_acc: 0.7563 - val_loss: 0.1432 - val_acc: 0.9550 - val_top1_acc: 0.2750 - val_top2_acc: 0.7200 - val_top3_acc: 0.8000
# Epoch 96/100
# 25/25 [==============================] - 171s 7s/step - loss: 0.0303 - acc: 0.9887 - top1_acc: 0.2537 - top2_acc: 0.7025 - top3_acc: 0.7925 - val_loss: 0.1100 - val_acc: 0.9650 - val_top1_acc: 0.2450 - val_top2_acc: 0.5300 - val_top3_acc: 0.9750
# Epoch 97/100
# 25/25 [==============================] - 166s 7s/step - loss: 0.0351 - acc: 0.9887 - top1_acc: 0.2537 - top2_acc: 0.6050 - top3_acc: 0.9125 - val_loss: 0.2300 - val_acc: 0.9450 - val_top1_acc: 0.2750 - val_top2_acc: 0.7450 - val_top3_acc: 0.7800
# Epoch 98/100
# 25/25 [==============================] - 164s 7s/step - loss: 0.0177 - acc: 0.9925 - top1_acc: 0.2550 - top2_acc: 0.7250 - top3_acc: 0.7613 - val_loss: 0.1765 - val_acc: 0.9450 - val_top1_acc: 0.2550 - val_top2_acc: 0.6550 - val_top3_acc: 0.6900
# Epoch 99/100
# 25/25 [==============================] - 165s 7s/step - loss: 0.0152 - acc: 0.9962 - top1_acc: 0.2512 - top2_acc: 0.7250 - top3_acc: 0.7550 - val_loss: 0.0595 - val_acc: 0.9800 - val_top1_acc: 0.2500 - val_top2_acc: 0.7250 - val_top3_acc: 0.7400
# Epoch 100/100
# 25/25 [==============================] - 164s 7s/step - loss: 0.0317 - acc: 0.9925 - top1_acc: 0.2500 - top2_acc: 0.7400 - top3_acc: 0.7613 - val_loss: 0.7298 - val_acc: 0.8200 - val_top1_acc: 0.2500 - val_top2_acc: 0.7650 - val_top3_acc: 0.8550
# Maximal validation accuracy: 100.00%

# %% [markdown]
# ## Comparison against the baseline

# %%
# The classification accuracies of the baseline and the pretraining + finetuning process:
def plot_training_curves(pretraining_history, finetuning_history, baseline_history):
    for metric_key, metric_name in zip(["acc", "loss"], ["accuracy", "loss"]):
        plt.figure(figsize=(8, 5), dpi=100)
        plt.plot(
            baseline_history.history[f"val_{metric_key}"], label="supervised baseline"
        )
        plt.plot(
            pretraining_history.history[f"val_p_{metric_key}"],
            label="self-supervised pretraining",
        )
        plt.plot(
            finetuning_history.history[f"val_{metric_key}"],
            label="supervised finetuning",
        )
        plt.legend()
        plt.title(f"Classification {metric_name} during training")
        plt.xlabel("epochs")
        plt.ylabel(f"validation {metric_name}")


plot_training_curves(pretraining_history, finetuning_history, baseline_history)

# %% [markdown]
# ## Save the models

# %%
model_dir = './models_all/'
os.mkdir(model_dir)
baseline_model.save(model_dir+'resnet50_100epochs_20k_unlabeled_1k_labeled')
# pretraining_model.save(model_dir+'pretrain_20epochs_20k_unlabeled_1k_labeled')
finetuning_model.save(model_dir+'finetune_100epochs_20k_unlabeled_1k_labeled')
print('did work')
# Out:
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 53). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ./models_all/resnet50_20epochs_20k_unlabeled_1k_labeled/assets
# INFO:tensorflow:Assets written to: ./models_all/resnet50_20epochs_20k_unlabeled_1k_labeled/assets
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 53). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ./models_all/finetune_20epochs_20k_unlabeled_1k_labeled/assets
# INFO:tensorflow:Assets written to: ./models_all/finetune_20epochs_20k_unlabeled_1k_labeled/assets
